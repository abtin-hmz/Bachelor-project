# %%
from transformers import AutoModel , AutoTokenizer
import pandas as pd
import torch
from sklearn.cluster import KMeans
from tqdm import tqdm

# %%
# If gpu is available set the device onto gpu otherwise cpu
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# read data
df = pd.read_csv("/content/drive/MyDrive/BA Project/productSampled.csv",encoding='utf-8')
# print a sample of data
df.head()
# Out:
#         id            category_name  \
# 0  1867826                میکروسکوپ
# 1  9418195  پرینتر لیزری و چند کاره
# 2   527022             منگنه و پانچ
# 3  3190482  فلاسک، قمقمه و ظروف سفر
# 4  5297025            مخلوط کن برقی
#
#                                               titles  min_price  max_price  \
# 0            میکروسکوپ اپتیکی سلسترون مدل 44121 cgl   1900000.0  2082000.0
# 1   پرینتر حرارتی canon selphy cp1000 پرينتر چاپ ...        NaN        NaN
# 2   دستگاه منگنه فلزی مپد مدل essentials کد e 352...    50000.0    65000.0
# 3   فلاسک هنری مدل roxana 450 کد sm 259 فلاسک هنر...   359000.0   359000.0
# 4   مخلوط کن پاناسونیک mx n800g آسیاب مخلوط کن پا...  1280000.0  1449000.0
#
#       avg_price  min_num_shops  max_num_shops  avg_num_shops
# 0  1.928314e+06              1              2       1.655303
# 1           NaN              0              0       0.000000
# 2  6.357542e+04              1              1       1.000000
# 3  3.590000e+05              0              1       0.054545
# 4  1.332843e+06              6             12       9.434912

# %%
# print number of each category sample
df['category_name'].value_counts()
# Out:
# category_name
# کتاب و مجلات                     1410
# کیف و کاور گوشی                   979
# ساعت مچی عقربه‌ ای و دیجیتالی     699
# فایل‌های دانلودی                  679
# کیف و کوله                        376
#                                  ...
# بارهنگ                              1
# طلق و شیرازه                        1
# چراغ اسپورت خودرو                   1
# سبزی خشک کن                         1
# شوفاژ برقی                          1
# Name: count, Length: 2667, dtype: int64

# %%
number_of_categories = len(df['category_name'].value_counts().index)
number_of_categories
# Out:
# 2667

# %%
tokenizer = AutoTokenizer.from_pretrained("sbunlp/fabert")
embedder = AutoModel.from_pretrained("sbunlp/fabert").to(DEVICE)
# Out:
# Some weights of BertModel were not initialized from the model checkpoint at sbunlp/fabert and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
def format_instruction(sample):
    return f"""
        {sample['category_name']}
        [SEP]
        {sample['titles']}
    """.strip()

# %%
prompts = []
for idx in tqdm(range(len(df))):
    prompts.append(
        format_instruction(df.iloc[idx])
    )
# Out:
# 100%|██████████| 36123/36123 [00:01<00:00, 18683.83it/s]

# %%
import torch
from tqdm import tqdm

# Define your batch size
BATCH_SIZE = 64
MAX_SENTENCE_LENGTH = 128

embeds = []
num_batches = len(prompts) // BATCH_SIZE + (1 if len(prompts) % BATCH_SIZE != 0 else 0)

for batch_idx in tqdm(range(num_batches)):
    # Determine the start and end indices of the current batch
    start_idx = batch_idx * BATCH_SIZE
    end_idx = min((batch_idx + 1) * BATCH_SIZE, len(prompts))

    # Get the batch of prompts
    batch_prompts = prompts[start_idx:end_idx]

    # Tokenize the batch of prompts
    tokenized_texts = tokenizer(batch_prompts, return_tensors="pt", truncation=True, padding=True, max_length=MAX_SENTENCE_LENGTH)

    # Move tokenized tensors to the GPU (if available)
    input_ids = tokenized_texts['input_ids'][:,:MAX_SENTENCE_LENGTH].to(DEVICE)
    attention_mask = tokenized_texts['attention_mask'][:,:MAX_SENTENCE_LENGTH].to(DEVICE)

    # Get embeddings for the batch
    with torch.no_grad():  # Ensure gradients are not computed for efficiency
        out = embedder(input_ids, attention_mask).last_hidden_state.mean(dim=1).cpu().detach().numpy()

    # Append embeddings to the list
    embeds.extend(out)
# Out:
# 100%|██████████| 565/565 [03:00<00:00,  3.13it/s]

# %%
class KMeans:
    def __init__(self, n_clusters, max_iter=100, tol=1e-4):
        self.n_clusters = n_clusters
        self.max_iter = max_iter
        self.tol = tol
        self.centroids = None

    def initialize_centroids(self, X):
        # Randomly choose `n_clusters` points from X as initial centroids
        indices = torch.randperm(X.size(0))[:self.n_clusters]
        self.centroids = X[indices]

    def compute_distances(self, X):
        # Compute the distance between each point and each centroid
        distances = torch.cdist(X, self.centroids, p=2)
        return distances

    def fit(self, X):
        # Move data to GPU if available
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        X = X.to(device)

        # Initialize centroids
        self.initialize_centroids(X)

        for i in tqdm(range(self.max_iter)):
            old_centroids = self.centroids.clone()

            # Step 1: Assign clusters based on the closest centroid
            distances = self.compute_distances(X)
            cluster_labels = torch.argmin(distances, dim=1)

            # Step 2: Recompute centroids
            new_centroids = torch.stack([X[cluster_labels == k].mean(dim=0) for k in range(self.n_clusters)])

            # Check for convergence (using L2 norm)
            if torch.norm(new_centroids - old_centroids, p=2) < self.tol:
                print(f'Converged at iteration {i}')
                break

            self.centroids = new_centroids

        # Store the final cluster assignments
        return cluster_labels.cpu()

    def predict(self, X):
        X = X.to(self.centroids.device)  # Make sure data is on the same device as centroids
        distances = self.compute_distances(X)
        return torch.argmin(distances, dim=1).cpu()

# %%
import torch
import numpy as np

embeds_array = np.vstack(embeds)  # Stack the list of numpy arrays into one 2D array
embeds_tensor = torch.tensor(embeds_array)  # Convert to PyTorch tensor
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
embeds_tensor = embeds_tensor.to(device)
kmeans = KMeans(n_clusters=1000, max_iter=10000,tol=1e-4)
cluster_labels = kmeans.fit(embeds_tensor)
print(cluster_labels)
# Out:
#   0%|          | 46/10000 [00:04<18:00,  9.21it/s]
# Converged at iteration 46
# tensor([854, 312, 746,  ..., 815, 685, 359])

# %%
cluster_labels = np.array(cluster_labels)
print("Cluster assignments:", cluster_labels)
# Out:
# Cluster assignments: [854 312 746 ... 815 685 359]

# %%
df = pd.read_csv("/content/drive/MyDrive/BA Project/productSampled.csv",encoding='utf-8')
df['cluster_label'] = cluster_labels

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36123 entries, 0 to 36122
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             36123 non-null  int64
#  1   category_name  36123 non-null  object
#  2   titles         36123 non-null  object
#  3   min_price      31172 non-null  float64
#  4   max_price      31172 non-null  float64
#  5   avg_price      31172 non-null  float64
#  6   min_num_shops  36123 non-null  int64
#  7   max_num_shops  36123 non-null  int64
#  8   avg_num_shops  36123 non-null  float64
#  9   cluster_label  36123 non-null  int64
# dtypes: float64(4), int64(4), object(2)
# memory usage: 2.8+ MB

# %%
df.to_csv('/content/drive/MyDrive/BA Project/productClustered3.csv', index=False,encoding='utf-8-sig')

# %%
df = df.groupby("cluster_label")
for cluster_label, group in df:
    print(f"Cluster {cluster_label}:")
    print(list(set(group['category_name'].tolist())))  # List of category names in this cluster
    print("-" * 50)  # Separator between clusters
# Out:
# Cluster 0:
# ['تبر، بیل و کلنگ', 'سوهان و سنباده کارگاهی', 'قیچی و ابزار باغبانی', 'لوازم جانبی ابزارآلات', 'سیم لخت\u200cکن و پرس کابل', 'چمن زن و داس موتوری', 'پشم چین دام', 'قلم تراش و غلاف', 'قاشق، چنگال و کارد', 'سنبه و لوازم نشانه گذاری', 'قیچی ورق و مفتول بر', 'سایر لوازم صافکاری', 'سنباده دیسکی، نواری و لرزان', 'شیار زن، کاشی و مرمر بر', 'فرز و مینی فرز', 'شانه و برس', 'میخ، پیچ و رول پلاک', 'سایر ابزار دستی و تجهیزات کارگاهی', 'سوسیس و کالباس']
# --------------------------------------------------
# Cluster 1:
# ['موکت', 'کف پوش، دیوار پوش و پارکت']
# --------------------------------------------------
# Cluster 2:
# ['سایر لوازم تزئینی خودرو', 'طبق خودرو', 'آرم خودرو', 'سایر لوازم خودرو']
# --------------------------------------------------
# Cluster 3:
# ['مکرومه بافی', 'پولک و منجوق']
# --------------------------------------------------
# Cluster 4:
# ['سه چرخه', 'کامیون و تریلی اسباب بازی', 'ماشین، قطار، کشتی اسباب بازی', 'موتور اسباب بازی', 'ماکت ماشین', 'اتوبوس و مینی بوس اسباب بازی', 'ماشین اسباب بازی', 'ماشین کنترلی', 'ماشین موزیکال', 'ماکت موتور']
# --------------------------------------------------
# Cluster 5:
# ['فشارسنج پزشکی', 'توستر نان', 'رم کامپیوتر', 'پنل آیفون صوتی و تصویری', 'کابل و تبدیل Lightning', 'اسپیکر و سیستم صوتی', 'وبکم و دوربین\u200cهای کنفرانس', 'ملودیکا', 'قلم نوری', 'فن کیس', 'خودکار', 'پرینتر جوهر افشان', 'کابل و تبدیل Type C', 'پخش خودرو', 'سایر لوازم جانبی ادوات موسیقی', 'کابل و تبدیل AUX', 'سه پایه دوربین', 'دوربین عکاسی و فیلمبرداری', 'تجهیزات جانبی فیلمبرداری', 'صحافی', 'مانیتور صنعتی و ویدیو وال', 'لوازم جانبی قطعات کامپیوتر', 'اسکنر', 'پایه نگهدارنده گوشی و تبلت', 'سوییچ و اسپلیتر', 'سایر لوازم جانبی کامپیوتر و لپ تاپ', 'باتری دوربین', 'تمیز کننده لوازم دیجیتالی', 'کیبورد لپ تاپ', 'ترانزیستور', 'ساب و بلندگو خودرو', 'کابل و تبدیل USB', 'اکشن فیگور', 'سایر انواع فن و خنک\u200cکننده', 'باتری لپ تاپ', 'تردمیل', 'آنتن و تقویت کننده شبکه', 'ابزار دقیق و اندازه\u200cگیری', 'کیبورد و میدی کنترلر', 'میکسر صدا', 'ساز دهنی', 'کابل و تبدیل HDMI', 'میکروفن', 'محافظ صفحه نمایش تبلت', 'ست ماوس و کیبورد', 'شارژر فندکی خودرو', 'لنز دوربین', 'کارت صدا استودیو', 'ماوس', 'بازی پلی استیشن', 'هدفون، هدست و هندزفری', 'کابل پرینتر', 'اف ام پلیر خودرو', 'میز تلویزیون', 'کتاب و مجلات', 'محافظ صفحه نمایش گوشی', 'پرینتر سه بعدی و لوازم جانبی', 'مادربورد', 'کابل شبکه', 'ساندبار', 'سابووفر و آمپلی\u200c فایر', 'نرم افزار', 'سرور', 'هاب USB', 'تبلت', 'ماشین\u200c حساب', 'شارژر لپ تاپ', 'سوکت و اتصالات تلفن', 'بارکد خوان', 'کامپیوتر های All in one', 'کیبورد', 'تخته رسم', 'پاور کامپیوتر', 'قلم لمسی', 'مانیتور', 'پنکه خودرو', 'ماژول WIFI و بلوتوث']
# --------------------------------------------------
# Cluster 6:
# ['اکسس پوینت و رادیو وایرلس', 'ضبط\u200cکننده صدا', 'میکروفن', 'ساب و بلندگو خودرو', 'پنل آیفون صوتی و تصویری', 'آمپلی فایر خودرو', 'رادیو و گرامافون', 'اسپیکر و سیستم صوتی', 'سابووفر و آمپلی\u200c فایر', 'اف ام پلیر خودرو', 'لامپ LED']
# --------------------------------------------------
# Cluster 7:
# ['ریموت کنترل', 'مانیتور آیفون تصویری', 'سایر تجهیزات ساختمان', 'ریموت دزدگیر خودرو', 'دزدگیر اماکن و لوازم جانبی']
# --------------------------------------------------
# Cluster 8:
# ['سایر پوشاک زنانه', 'لباس زیر و لباس خواب زنانه', 'کت و شلوار مردانه', 'فایل\u200cهای دانلودی', 'شلوار و سرهمی زنانه', 'حوله تن پوش', 'لباس مجلسی زنانه', 'پیراهن مردانه', 'لگینگ و ساپورت زنانه', 'شلوار دخترانه', 'کلاه و شال گردن مردانه', 'کاپشن، بارانی و پالتو زنانه', 'نیم تنه و کراپ زنانه', 'شلوار رسمی و راحتی مردانه', 'ژاکت و پلیور مردانه', 'شومیز و تونیک دخترانه', 'لباس کار و یونیفرم', 'تاپ و تیشرت زنانه', 'دامن زنانه', 'مانتو دخترانه', 'لباس زیر مردانه', 'هودی زنانه', 'سایر لباس ورزشی زنانه', 'بلوز و پیراهن زنانه', 'لباس بارداری', 'سویشرت و هودی مردانه', 'شومیز و تونیک زنانه']
# --------------------------------------------------
# Cluster 9:
# ['تاپر کیک', 'ظروف یکبار مصرف', 'شکلات، تافی و آبنبات', 'آجیل و شکلات خوری', 'ژله و دسر', 'سایر ابزار قنادی', 'کیک مناسبتی', 'شیرینی و میوه خوری', 'یخچال، فریزر و تاپینگ فروشگاهی', 'شکر پاش', 'قالب شیرینی پزی و دسر', 'قالب پیتزا', 'کیک، کلوچه و کوکی']
# --------------------------------------------------
# Cluster 10:
# ['چای', 'چای ساز', 'مکمل دیابت', 'جنسینگ', 'دمنوش', 'دارچین', 'زعفران']
# --------------------------------------------------
# Cluster 11:
# ['فویل آلومینیوم', 'بست و براکت', 'مخازن و منابع', 'لوله و خرطومی برق', 'سایر عایق صوتی و حرارتی', 'سایر تجهیزات ساختمان', 'لوله و اتصالات', 'ایزوگام', 'تلمبه', 'عایق رطوبتی', 'سیم چین و کف چین', 'قرنیز و سایر پروفیل\u200cها']
# --------------------------------------------------
# Cluster 12:
# ['محصولات مسی', 'سایر لوازم هنرهای دستی']
# --------------------------------------------------
# Cluster 13:
# ['سایر پوشاک زنانه', 'الگوی لباس', 'پیراهن مردانه', 'لباس زیر مردانه', 'لباس زیر و لباس خواب زنانه', 'هودی زنانه', 'لباس سگ و گربه', 'تیشرت و پولوشرت پسرانه', 'شلوار و سرهمی زنانه', 'پیراهن دخترانه', 'تیشرت و پولوشرت مردانه', 'نیم تنه و کراپ زنانه', 'سایر لباس ورزشی زنانه', 'بلوز و پیراهن زنانه', 'تاپ و تیشرت زنانه']
# --------------------------------------------------
# Cluster 14:
# ['سشوار صنعتی', 'مکان\u200c یاب و قبله نما']
# --------------------------------------------------
# Cluster 15:
# ['سایر لوازم جانبی ادوات موسیقی', 'گیتار', 'محتوای آموزشی', 'پنل آکوستیک', 'کیف و کاور ادوات موسیقی', 'پایه و استند ادوات موسیقی', 'نرم افزار']
# --------------------------------------------------
# Cluster 16:
# ['کتاب و مجلات']
# --------------------------------------------------
# Cluster 17:
# ['شوید', 'زرشک', 'پودر پیاز', 'نخود', 'زنجبیل']
# --------------------------------------------------
# Cluster 18:
# ['ساندویچ ساز و وافل ساز']
# --------------------------------------------------
# Cluster 19:
# ['بادکنک', 'تزیینات کریسمس']
# --------------------------------------------------
# Cluster 20:
# ['تابلو فرش']
# --------------------------------------------------
# Cluster 21:
# ['لوازم جانبی ابزارآلات', 'پایه ابزارآلات']
# --------------------------------------------------
# Cluster 22:
# ['محصولات مسی', 'زیر لیوانی و زیر قابلمه\u200cای', 'کفگیر و ملاقه', 'ظروف تزیینی', 'سینی پذیرایی', 'پارچ و لیوان', 'جای برنج', 'آبچکان و جاظرفی آشپزخانه', 'دیس و بشقاب', 'کاسه و پیاله', 'سوفله خوری']
# --------------------------------------------------
# Cluster 23:
# ['سایر شلوار خردسال و نوجوان']
# --------------------------------------------------
# Cluster 24:
# ['سایر اسباب\u200cبازی و سرگرمی', 'سرگرمی نوزاد', 'خمیر بازی', 'اسباب بازی حباب ساز', 'لوازم شن بازی', 'ماشین موزیکال', 'ارگ و کیبورد اسباب بازی', 'پیانو اسباب بازی', 'اسباب بازی فعالیت و تحرک', 'روروک و واکر کودک', 'ابزار اسباب بازی', 'جعبه و گوی موزیکال', 'عروسک', 'گهواره و تاب برقی', 'لوازم پزشکی اسباب بازی', 'تجهیزات بازی پارکی', 'مسواک', 'اسباب بازی آموزشی', 'لوازم خانگی اسباب بازی']
# --------------------------------------------------
# Cluster 25:
# ['تجهیزات گلخانه\u200cای', 'گلدان و گل مصنوعی', 'چمن مصنوعی و لوازم جانبی']
# --------------------------------------------------
# Cluster 26:
# ['سایر تجهیزات نگهداری حیوانات خانگی', 'سگ دست و شغال دست خودرو', 'شیر خشک و غذای کودک', 'غذا و تشویقی گربه', 'غذا و تشویقی سگ', 'سایر تجهیزات پزشکی', 'غذای طوطی سانان', 'غذای ماهی و میگو', 'شیر لبنی', 'چای', 'سایر غذا و مکمل حیوانات خانگی', 'نودل', 'موسیر', 'تن ماهی', 'ماهی', 'ترشیجات', 'سوپ و آش', 'ماکارونی، پاستا و رشته', 'کود و مکمل آکواریوم', 'غذای خرگوش', 'خمیر مالت گربه', 'بادام', 'پروتئین وی']
# --------------------------------------------------
# Cluster 27:
# ['هواپیما و هلی کوپتر اسباب بازی', 'ربات اسباب بازی', 'فیجت و اسپینر', 'فایل\u200cهای دانلودی', 'لوازم شوخی و سرگرمی', 'موتور اسباب بازی', 'فکری، پازل و لگو']
# --------------------------------------------------
# Cluster 28:
# ['لوازم جانبی هارد', 'سایر لوازم جانبی کامپیوتر و لپ تاپ', 'کابل شارژ پاور بانک', 'کابل و سوکت سیستم صوتی خودرو', 'کابل شبکه', 'منبع تغذیه UPS', 'تجهیزات جانبی ماینینگ', 'محافظ و نگهدارنده کابل', 'کابل برق کامپیوتر و لپ تاپ', 'کابل افزایش طول', 'تجهیزات TRX', 'تجهیزات فیبر نوری']
# --------------------------------------------------
# Cluster 29:
# ['باربیکیو و کباب\u200cپز', 'فایل\u200cهای دانلودی', 'سایر تجهیزات آشپزخانه صنعتی']
# --------------------------------------------------
# Cluster 30:
# ['لیف کودک و نوزاد', 'شوینده ظروف', 'جای صابون و مایع دستشویی', 'دستمال نظافت', 'ضدعفونی کننده دست', 'پاک کننده سطوح', 'حوله حمام', 'سایر عروسک', 'سایر لوازم مصرفی خودرو', 'شوینده و نرم کننده لباس و حوله', 'حوله استخری', 'واکس و اسپری تمیزکننده خودرو', 'واکس و براق کننده کیف و کفش', 'مایع دستشویی']
# --------------------------------------------------
# Cluster 31:
# ['سایر پوشاک زنانه', 'کت و شلوار مردانه', 'دکمه لباس', 'بلوز و پیراهن زنانه', 'کت و جلیقه زنانه', 'لباس مجلسی زنانه', 'پیراهن دخترانه', 'دامن زنانه']
# --------------------------------------------------
# Cluster 32:
# ['چادر و کلبه بازی', 'کیف پول و اقلام کوچک', 'فایل\u200cهای دانلودی', 'لباس شنا مردانه و پسرانه', 'سطل کودک و باکس پوشک', 'بالش طبی', 'پتو دو نفره', 'کلاه و شال گردن مردانه', 'چتر و سایه\u200cبان', 'ورزش\u200cهای رزمی', 'سی\u200c\u200cدی فیلم و سریال', 'کیف و کوله', 'کلاژ و فرش پوست', 'سایر تیشرت خردسال و نوجوان', 'عروسک روسی', 'تاپ و تیشرت زنانه', 'سایر پوشاک خردسال و نوجوان', 'شال', 'کیف وسایل کودک', 'بوت و نیم بوت خردسال و نوجوان', 'قنداق نوزاد', 'سایر کفش و صندل خردسال و نوجوان', 'کلاه کاسکت', 'لباس نوزاد و کودک', 'صندلی غذاخوری کودک', 'لوازم خانگی اسباب بازی', 'پیشبند کودک']
# --------------------------------------------------
# Cluster 33:
# ['کراوات', 'کمربند مردانه', 'کمربند زنانه', 'ساق دست']
# --------------------------------------------------
# Cluster 34:
# ['آینه دکوراتیو', 'ابزار پتینه', 'سایر لوازم هنرهای دستی', 'سنگ ساختمانی', 'کاشی، سرامیک و موزاییک', 'ظروف تزیینی', 'کتابخانه', 'سنگ قبر', 'ملزومات پرده', 'مینا کاری', 'دیوار کوب', 'مصالح پیش ساخته', 'آباژور و چراغ خواب', 'گلدان و گل مصنوعی', 'تابلو و مجسمه', 'رومیزی و پرده', 'سینی پذیرایی', 'سایر لوازم تزیینی منزل', 'تابلو علائم و دستورالعمل\u200cها', 'بلوک و آجر', 'آهن\u200cآلات ساختمانی', 'قطعات و لوازم جانبی صنایع چوبی']
# --------------------------------------------------
# Cluster 35:
# ['سایر انواع فن و خنک\u200cکننده', 'هیتر و هویه', 'رادیاتور پنلی و پره\u200cای', 'کولر آبی', 'مشعل گازی', 'آبسرد کن', 'فن هیتر', 'چیلر و مینی چیلر', 'دیگ فولادی', 'بخاری گازی', 'فن کویل', 'هواکش و فن تهویه', 'لوازم جانبی و قطعات کولر', 'شوفاژ برقی', 'پکیج دیواری و زمینی', 'هیتر گرمایشی', 'گرمکن استخر و جکوزی', 'لوازم جانبی و قطعات پمپ']
# --------------------------------------------------
# Cluster 36:
# ['بازی کامپیوتری', 'سایر اسباب\u200cبازی و سرگرمی', 'کتاب و مجلات']
# --------------------------------------------------
# Cluster 37:
# ['سایر جوراب بچگانه', 'دستکش زنانه', 'جوراب نوزادی', 'فایل\u200cهای دانلودی', 'جوراب زنانه', 'جوراب شلواری دخترانه', 'جوراب مردانه', 'ساق دست', 'جوراب پسرانه', 'جوراب دخترانه']
# --------------------------------------------------
# Cluster 38:
# ['کاور و شال مبل', 'مکرومه بافی', 'شال', 'کلاه و شال گردن زنانه', 'سایر حوله', 'گیره شال و روسری', 'کلاه و شال گردن مردانه', 'ست روسری و کیف', 'روسری', 'کلاه و شال گردن بچگانه', 'انواع پارچه']
# --------------------------------------------------
# Cluster 39:
# ['سایر لامپ و چراغ', 'چراغ ریلی', 'ریسه و شلنگ نوری', 'لوازم جانبی نور و روشنایی', 'چراغ دفنی', 'قاب لامپ و چراغ', 'پنل خورشیدی', 'چراغ خطی و زیر کابینتی', 'روشنایی و نورپردازی هوشمند', 'رقص نور', 'چراغ نفتی', 'لامپ هالوژن', 'لوستر و چراغ تزئینی', 'چراغ پنلی', 'آباژور و چراغ خواب', 'چراغ دیواری', 'چراغ استخر و سونا', 'پروژکتور و وال واشر', 'چراغ قوه و چراغ پیشانی', 'چراغ سقفی', 'لامپ LED', 'چراغ حیاطی و پارکی']
# --------------------------------------------------
# Cluster 40:
# ['سایر پوشاک زنانه', 'دمپایی و صندل خردسال و نوجوان', 'کیف پول و اقلام کوچک', 'بوت و نیم بوت زنانه', 'شلوارک و شورت ورزشی', 'کفش کوهنوردی', 'صندل و دمپایی زنانه', 'کفش مجلسی مردانه', 'انگشتر نقره', 'سایر شلوار خردسال و نوجوان', 'دستکش پسرانه', 'لباس مجلسی زنانه', 'سویشرت ورزشی زنانه', 'کتانی و کفش اسپرت مردانه', 'لباس شنا مردانه و پسرانه', 'چمدان و ساک', 'کتانی و کفش اسپرت زنانه', 'کلاه و شال گردن مردانه', 'کاپشن، بارانی و پالتو زنانه', 'کفش کالج و روزمره مردانه', 'بوت و نیم بوت مردانه', 'کمربند دخترانه', 'شلوار رسمی و راحتی مردانه', 'کیف و کوله', 'کفش فوتبال', 'صندل و دمپایی مردانه', 'سایر پوشاک مردانه', 'سایر کفش و صندل زنانه', 'گردنبند نقره', 'سویشرت و شلوار ورزشی مردانه', 'کتانی و کفش اسپرت', 'پاپوش و کفش نوزاد و کودک', 'کاپشن، بارانی و پالتو مردانه', 'کتانی و کفش اسپرت خردسال', 'بوت و نیم بوت خردسال و نوجوان', 'جوراب مردانه', 'سایر کفش و صندل خردسال و نوجوان', 'کفش پاشنه بلند و مجلسی زنانه', 'سویشرت و هودی مردانه', 'لباس شنا زنانه و دخترانه']
# --------------------------------------------------
# Cluster 41:
# ['آجیل و شکلات خوری', 'آبکش، لگن و سبد', 'ظرف عسل و مربا', 'شیرینی و میوه خوری', 'مگنت', 'جعبه پذیرایی', 'محصولات مسی', 'ظروف تزیینی', 'قندان', 'آبچکان و جاظرفی آشپزخانه', 'درپوش سیلیکونی ظروف', 'چای', 'وارمر قوری', 'کاسه و پیاله', 'سوفله خوری', 'ماگ', 'پارچ و لیوان', 'سایر لوازم تزیینی منزل', 'سینی پذیرایی', 'کتری و قوری', 'دمنوش ساز', 'تراش', 'سرویس چای خوری']
# --------------------------------------------------
# Cluster 42:
# ['لباس زیر و لباس خواب زنانه', 'لباس زیر دخترانه']
# --------------------------------------------------
# Cluster 43:
# ['کارواش و لوازم جانبی خودرو', 'رادیاتور بخاری خودرو', 'سایر لوازم یدکی خودرو', 'پمپ بنزین خودرو', 'شیلنگ رادیاتور خودرو', 'رادیاتور کولر خودرو', 'کوئل خودرو', 'ترموستات خودرو', 'رادیاتور آب خودرو']
# --------------------------------------------------
# Cluster 44:
# ['سایر پوشاک زنانه', 'کمربند مردانه', 'سایر کفش مردانه', 'سایر اکسسوری مردانه', 'سایر لباس ورزشی مردانه', 'کفش طبی مردانه']
# --------------------------------------------------
# Cluster 45:
# ['نایلون دسته دار', 'ظروف یکبار مصرف', 'سلفون بسته بندی', 'کیسه زباله', 'رنگ خوراکی', 'لوازم بسته\u200cبندی', 'پوشه', 'لوازم شن بازی', 'گیره کاغذ', 'زیپ کیپ', 'کیسه فریزر', 'لوازم جانبی صحافی']
# --------------------------------------------------
# Cluster 46:
# ['سایر انواع انگشتر', 'سایر انواع گردنبند', 'سایر انواع گوشواره']
# --------------------------------------------------
# Cluster 47:
# ['کارواش و لوازم جانبی خودرو', 'پلوس خودرو', 'سیم و سوکت خودرو', 'زنجیر چرخ خودرو', 'موتور فن بخاری و کولر خودرو', 'سایر لوازم یدکی خودرو', 'آینه بغل خودرو', 'کیلومتر خودرو و قطعات جانبی', 'جک کاپوت و صندوق عقب خودرو', 'تسمه تایم خودرو', 'کروز کنترل خودرو', 'جعبه فرمان خودرو', 'ترموستات خودرو', 'استارت خودرو', 'قفل فرمان و پدال خودرو', 'سیلندر ترمز خودرو', 'سنسور دریچه گاز خودرو', 'کاسه نمد گیربکس خودرو', 'سنسور اکسیژن خودرو', 'قلم خش گیر', 'درب رادیاتور خودرو', 'قفل رینگ خودرو', 'بالابر شیشه خودرو', 'کیت کلاچ خودرو', 'درجه داخل باک خودرو', 'کیت جلوبندی خودرو', 'دستگیره خودرو', 'سنسور دنده عقب خودرو', 'کمک فنر خودرو', 'آفتابگیر خودرو', 'میل لنگ خودرو', 'دسته موتور خودرو', 'طبق خودرو', 'کلید برقی خودرو', 'باربند خودرو', 'پا رکابی خودرو', 'سپر خودرو', 'فیلتر هوا خودرو', 'قطعات و لوازم جانبی دوچرخه', 'قاب و حلقه کیلومتر شمار', 'سیبک فرمان و قرقری خودرو', 'رینگ پیستون خودرو', 'پیچ و قطعات چرخ خودرو', 'رینگ چرخ خودرو', 'تسمه دینام و پروانه خودرو', 'شبرنگ خودرو', 'بوش طبق خودرو', 'گردگیر جعبه فرمان خودرو', 'سر دنده خودرو', 'کاسه نمد پلوس خودرو', 'ساب و بلندگو خودرو', 'سایر لوازم خودرو', 'تجهیزات تعمیرگاهی خودرو', 'کوئل خودرو', 'بوستر ترمز خودرو', 'برف پاک کن خودرو', 'کاسه چرخ خودرو']
# --------------------------------------------------
# Cluster 48:
# ['چادر و کلبه بازی', 'سایر اسباب\u200cبازی و سرگرمی', 'سایر تجهیزات جوندگان', 'سرگرمی نوزاد', 'اسباب بازی حباب ساز', 'ماشین، قطار، کشتی اسباب بازی', 'فرفره انفجاری', 'سایر عروسک', 'آغوشی', 'خوراکی و اسباب بازی شانسی', 'لوازم شن بازی', 'قطار اسباب بازی', 'آویز و جاکلیدی', 'عروسک موزیکال', 'شورت گره ای و آموزشی کودک', 'کامیون و تریلی اسباب بازی', 'عروسک باربی', 'پیانو اسباب بازی', 'عروسک پولیشی', 'چتر و سایه\u200cبان', 'روروک و واکر کودک', 'جامدادی', 'ابزار اسباب بازی', 'تجهیزات بازی بادی', 'بلز', 'ماکت اسلحه', 'اشیاء قدیمی و کلکسیونی', 'عروسک', 'عروسک روسی', 'تبدیل توالت و لگن آموزشی', 'گهواره و تاب برقی', 'عروسک حیوانات', 'تخت خواب کودک و نوزاد', 'کیف وسایل کودک', 'تجهیزات بازی پارکی', 'مسواک', 'سایر تفنگ اسباب بازی', 'اسباب بازی آموزشی', 'عروسک السا', 'ماشین اسباب بازی', 'سایر اسباب بازی موزیکال', 'لوازم خانگی اسباب بازی', 'پیشبند کودک']
# --------------------------------------------------
# Cluster 49:
# ['جعبه ابزار', 'سایر تجهیزات پزشکی', 'سایر ماشین\u200cها و تجهیزات اداری', 'قطعات و لوازم جانبی پولیش', 'ترولی پزشکی', 'ابزار و تجهیزات تعمیر موبایل', 'دستگاه پولیش', 'مهر و استامپ', 'لوازم جانبی دستگاه\u200cهای زیبایی', 'ابزار جراحی', 'پستانک و ملزومات', 'فیزیوتراپی و لوازم جانبی', 'مواد و تجهیزات دندانپزشکی', 'پاراوان و پارتیشن', 'لوازم رزین', 'لوازم جانبی صحافی']
# --------------------------------------------------
# Cluster 50:
# ['قنداق نوزاد', 'انواع پارچه', 'لباس نوزاد و کودک', 'پیشبند کودک']
# --------------------------------------------------
# Cluster 51:
# ['تخمه و مغزهای طعم\u200cدار', 'بیکینگ پودر', 'مربا', 'زرشک', 'بیسکویت و ویفر', 'برگه زردآلو', 'خرما', 'آلو خشک', 'عسل', 'سرکه', 'شیر خشک و غذای کودک', 'سایر میوه خشک', 'پشمک', 'غلات صبحانه', 'آرد', 'آلبالو خشک', 'زنجبیل', 'زردچوبه', 'دارچین', 'روغن خوراکی', 'قند و شکر', 'پودر دکلره', 'نان', 'باقلوا', 'کتاب و مجلات', 'پودر سفیده تخم مرغ', 'بادام هندی', 'زعفران', 'ارده و حلوا شکری', 'مکمل بلغم زدا', 'پسته', 'سبوس، جوانه و سویق', 'شکلات، تافی و آبنبات', 'کشمش و مویز', 'کشک', 'هل', 'شکلات و کره صبحانه', 'بادام', 'لیمو عمانی', 'گز ، پولکی و نوقا', 'آرد و پودر سوخاری', 'غلات', 'شربت', 'انجیر خشک', 'کیک، کلوچه و کوکی']
# --------------------------------------------------
# Cluster 52:
# ['سایر انواع انگشتر', 'گردنبند نقره', 'پلاک و زنجیر', 'پابند نقره', 'ترانسفر', 'سایر انواع گردنبند', 'گوشواره استیل', 'گردن بند طبی', 'گردنبند استیل', 'سایر انواع گوشواره']
# --------------------------------------------------
# Cluster 53:
# ['تجهیزات نظامی']
# --------------------------------------------------
# Cluster 54:
# ['چسب و پد درمانی', 'کرم و لوسیون کودک', 'گان و لباس بیمار', 'ترولی پزشکی', 'بهداشت و مراقبت پا', 'بهداشت بانوان', 'دستمال مرطوب کودک', 'مواد و تجهیزات دندانپزشکی', 'دستکش یکبار مصرف', 'ماساژور و لوازم ماساژ']
# --------------------------------------------------
# Cluster 55:
# ['سایر مصالح ساختمانی', 'فایل\u200cهای دانلودی']
# --------------------------------------------------
# Cluster 56:
# ['سایر جوراب ورزشی', 'دستکش نظافت', 'دستکش زنانه', 'جوراب زنانه', 'جوراب شلواری دخترانه', 'جوراب مردانه', 'جوراب دخترانه']
# --------------------------------------------------
# Cluster 57:
# ['موسیقی', 'محتوای آموزشی', 'فایل\u200cهای دانلودی', 'فاکتور و قبض رسید', 'کتاب های صوتی و الکترونیکی', 'اکشن فیگور', 'کتاب و مجلات']
# --------------------------------------------------
# Cluster 58:
# ['بوت و نیم بوت زنانه', 'بوت و نیم بوت مردانه']
# --------------------------------------------------
# Cluster 59:
# ['لوازم جانبی ساعت های معمولی و هوشمند', 'ساعت مچی عقربه\u200c ای و دیجیتالی']
# --------------------------------------------------
# Cluster 60:
# ['لاستیک موج گیر خودرو', 'لاستیک خودرو', 'بوش طبق خودرو']
# --------------------------------------------------
# Cluster 61:
# ['پیراهن مردانه', 'کمربند مردانه', 'لباس زیر مردانه', 'سویشرت زنانه', 'شلوار پسرانه']
# --------------------------------------------------
# Cluster 62:
# ['سایر تجهیزات پرورش دام و طیور', 'شانه و سبد مرغداری', 'طیور زنده', 'تخم مرغ', 'تجهیزات پرورش اسب و سوار کاری', 'تجهیزات پرورش زنبور', 'باکس و قفس جوندگان', 'ظرف آب و غذای جوندگان']
# --------------------------------------------------
# Cluster 63:
# ['دستبند چرمی', 'انگشتر حدید', 'مروارید', 'دستبند فیروزه', 'انگشتر نقره', 'دستبند سنگی و کریستال', 'انگشتر یاقوت', 'سایر انواع انگشتر', 'پلاک و زنجیر', 'سنگ فیروزه', 'گردنبند عقیق', 'انگشتر فیروزه', 'گردنبند نقره', 'انگشتر زمرد', 'انگشتر عقیق', 'گردنبند فیروزه', 'سایر انواع گردنبند', 'گردنبند رزینی', 'گردنبند طلا']
# --------------------------------------------------
# Cluster 64:
# ['دستگاه آسفالت بر', 'چکش', 'اره فارسی بر و اره میزی', 'چکش صافکاری', 'اره موتوری و زنجیری', 'پشم چین دام', 'اره پروفیل بر', 'فرغون و قطعات جانبی', 'چکش تخریب و دریل بتن کن', 'شمشاد زن', 'فرز و مینی فرز', 'منگنه کوب و میخکوب', 'چمن زن و داس موتوری']
# --------------------------------------------------
# Cluster 65:
# ['آلبوم عکس', 'سایر انواع ماکت', 'کاغذ و پوستر دیواری', 'پوستر و استیکر', 'سایر تیشرت خردسال و نوجوان', 'برچسب و لیبل', 'پیکسل', 'فایل\u200cهای دانلودی', 'بنر، اعلامیه و کتیبه', 'سایر عروسک', 'تم تولد', 'سایر لوازم جشن و هدیه', 'کارت پستال و عروسی']
# --------------------------------------------------
# Cluster 66:
# ['سایر عطر و ادکلن', 'خوشبو کننده هوا', 'عطر ادوپرفیوم مردانه', 'عود و جاعودی', 'عطر ادوتویلت زنانه', 'مام و اسپری', 'عطر ادوتویلت مردانه', 'عطر ادوپرفیوم زنانه', 'اسانس و اسانس سوز', 'مایع دستشویی', 'صابون']
# --------------------------------------------------
# Cluster 67:
# ['آهن\u200cآلات ساختمانی']
# --------------------------------------------------
# Cluster 68:
# ['دوش و علم دوش']
# --------------------------------------------------
# Cluster 69:
# ['آلبوم عکس', 'پوستر و استیکر', 'کیک مناسبتی', 'تم تولد', 'کارت هدیه']
# --------------------------------------------------
# Cluster 70:
# ['کیف آرایش', 'کیف و کاور عینک', 'کیف و کوله']
# --------------------------------------------------
# Cluster 71:
# ['لوله بر', 'آهنربا', 'تجهیزات راهنمای خطی', 'کره جغرافیا']
# --------------------------------------------------
# Cluster 72:
# ['پیتزا', 'مسواک', 'تسبیح', 'زغال', 'دمنوش', 'صابون', 'زعفران', 'زناشویی']
# --------------------------------------------------
# Cluster 73:
# ['روسری', 'شال']
# --------------------------------------------------
# Cluster 74:
# ['سایر لوازم جانبی ورزشی و تناسب اندام', 'کش ورزشی', 'تردمیل', 'کمربند ورزشی', 'تجهیزات یوگا', 'طناب ورزشی', 'حلقه لاغری', 'سایر تجهیزات بدنسازی', 'حلقه شنا']
# --------------------------------------------------
# Cluster 75:
# ['کیف و کاور گوشی']
# --------------------------------------------------
# Cluster 76:
# ['فیجت و اسپینر', 'کلیر بوک', 'نشانگر کتاب', 'میکرونیدلینگ درمارولر و درماپن', 'جای ادویه و پاسماوری', 'کاخن', 'پلاک و زنجیر', 'گریپ راکت', 'کانسیلر', 'دی لایت خودرو', 'هدلایت خودرو', 'تجهیزات بازی بادی', 'بالابر و پولیفت', 'خودکار', 'اسکیمر آکواریوم', 'نور آکواریوم', 'اسکیت کفشی و اسکیت بورد', 'سایر تجهیزات استودیویی', 'تاب ریلکسی', 'مام و اسپری', 'پکیج کادویی', 'پیرسینگ', 'بادپاش', 'رنگ مولتی سرفیس', 'تجهیزات یوگا', 'بیلیارد و لوازم جانبی', 'تجهیزات جانبی فیلمبرداری', 'اسکارف و دستمال سر']
# --------------------------------------------------
# Cluster 77:
# ['برنج ایرانی', 'لوبیا', 'غلات', 'برنج خارجی', 'نخود', 'برنج قهوه\u200cای']
# --------------------------------------------------
# Cluster 78:
# ['کمپرسور هوا و پمپ باد', 'جارو برقی صنعتی', 'شیلنگ و شیلنگ جمع کن', 'سایر تجهیزات پنوماتیک', 'فلوتر و شناور', 'پیستوله و گازوئیل پاش', 'جک سوسماری و روغنی', 'شعله افکن و سرپیک صنعتی', 'لوازم روانکاری', 'چرخ حمل بار', 'چمن زن و داس موتوری', 'شیلنگ آب و تجهیزات آبیاری', 'روغن صنعتی', 'گیربکس صنعتی', 'تجهیزات راهنمای خطی', 'سختی\u200cگیر و رسوب زدا', 'منقل و زغال سوز', 'ادوات و ماشین\u200cآلات کشاورزی', 'بلوور دمنده و مکنده', 'سمپاش و تجهیزات جانبی', 'مشعل گازوئیل سوز', 'بکس بادی', 'اره موتوری و زنجیری', 'هواکش و فن تهویه', 'سانتریفیوژ', 'موتور پمپ', 'مکمل سوخت و روغن', 'کف\u200cکش و لجن\u200cکش', 'پمپ خانگی و صنعتی', 'تجهیزات تعمیرگاهی خودرو']
# --------------------------------------------------
# Cluster 79:
# ['فایل\u200cهای دانلودی', 'دانگل بلوتوث']
# --------------------------------------------------
# Cluster 80:
# ['آلبوم عکس', 'آینه دکوراتیو', 'اسپند سوز', 'ظروف تزیینی', 'خاتم کاری', 'دستمال کاغذی', 'کتابخانه', 'میز تلویزیون']
# --------------------------------------------------
# Cluster 81:
# ['باتری دوربین', 'محتوای آموزشی', 'ابزار و تجهیزات تعمیر موبایل', 'سایر سنسور هوشمند', 'تجهیزات جانبی فیلمبرداری', 'کیف و کاور تجهیزات فیلمبرداری', 'محافظ لنز دوربین']
# --------------------------------------------------
# Cluster 82:
# ['ترانزیستور', 'منبع تغذیه سوییچینگ', 'تبدیل دو شاخه برق', 'دیود', 'خازن', 'فتوسل', 'آداپتور برق', 'سایر منبع تغذیه', 'سایر قطعات الکترونیکی', 'سایر تجهیزات شبکه و ارتباطات', 'مقاومت']
# --------------------------------------------------
# Cluster 83:
# ['حصیر و زیرانداز', 'تشک دو نفره', 'تشک نمدی', 'تشک میهمان', 'پتو دو نفره', 'پتو تک نفره', 'تشک مواج طبی', 'کیسه خواب', 'تشک بادی و مسافرتی', 'تشک تک نفره', 'پتو مسافرتی', 'چادر مسافرتی']
# --------------------------------------------------
# Cluster 84:
# ['سایر انواع انگشتر', 'دستبند چرمی', 'پلاک و زنجیر', 'انگشتر استیل', 'دستبند نقره', 'ست و نیم\u200c ست جواهرات', 'سایر انواع گردنبند', 'انگشتر طلا', 'پابند استیل', 'گردنبند طلا', 'سایر دستبند، پابند و آویز ساعت', 'سایر انواع گوشواره', 'گوشواره رزینی']
# --------------------------------------------------
# Cluster 85:
# ['ویتامین E', 'مکمل مس (Mass)', 'مکمل آمینو', 'نوشیدنی انرژی زا', 'سایر مکمل\u200c ورزشی و دارویی', 'مکمل سی ال ای (CLA)', 'مکمل کربوهیدرات', 'قرص جوشان', 'مکمل کلسیم', 'پروتئین وی']
# --------------------------------------------------
# Cluster 86:
# ['فایل\u200cهای دانلودی', 'مانتو، پانچ و رویه']
# --------------------------------------------------
# Cluster 87:
# ['آبگرمکن گازی', 'آبگرمکن برقی', 'سشوار']
# --------------------------------------------------
# Cluster 88:
# ['کیبورد لپ تاپ', 'قاب و بدنه لپ تاپ', 'باتری لپ تاپ', 'تاچ و ال سی دی لپ تاپ', 'تبلت', 'ترک پد و تاچ لپ تاپ', 'مینی کامپیوتر', 'شارژر لپ تاپ', 'شارژر تبلت', 'لپ تاپ و نوت بوک']
# --------------------------------------------------
# Cluster 89:
# ['محتوای آموزشی', 'کامپیوتر دسکتاپ', 'سیستم کنترل پیامکی', 'ربات کنترلی', 'کتابخانه', 'نرم افزار', 'برد توسعه']
# --------------------------------------------------
# Cluster 90:
# ['سایر پوشاک زنانه', 'مروارید', 'خرج کار', 'صندل و دمپایی زنانه', 'شیکر و قمقمه ورزشی', 'سایر عروسک', 'زیپ کیپ', 'لباس مجلسی زنانه', 'آینه کنسول', 'ست میز و صندلی غذاخوری', 'پیراهن مردانه', 'مانتو، پانچ و رویه', 'کیف و کوله', 'لباس فوتبال', 'خودکار', 'کفش والیبال', 'سایر کفش مردانه', 'صندل و دمپایی مردانه', 'جوراب آمبولی', 'کیف آرایش', 'انواع پارچه', 'دامن زنانه', 'کتانی و کفش اسپرت', 'لباس زیر مردانه', 'کفشور', 'کاموا', 'پوشه', 'سایر کفش و صندل خردسال و نوجوان', 'جوراب شلواری زنانه', 'تخت خواب', 'کفش ایمنی و کار', 'لباس نوزاد و کودک', 'سایر انواع گوشواره']
# --------------------------------------------------
# Cluster 91:
# ['قنداق نوزاد', 'عروسک باربی', 'سایر عروسک']
# --------------------------------------------------
# Cluster 92:
# ['درب خودرو', 'سایر لوازم یدکی خودرو', 'جراغ خطر اسپرت خودرو', 'آینه بغل خودرو', 'چراغ سقفی خودرو', 'چراغ جلو اسپرت خودرو', 'چراغ عقب اسپرت خودرو', 'دیاق سپر خودرو', 'چراغ راهنما خودرو', 'چراغ صندوق خودرو', 'چراغ خطر عقب خودرو', 'سایر لوازم صوتی و تصویری خودرو', 'جلو پنجره خودرو', 'سایر لوازم تزئینی خودرو', 'پروژکتور و مه شکن خودرو', 'دستگیره خودرو', 'چراغ جلو خودرو', 'سنسور دنده عقب خودرو', 'سوکت چراغ خودرو', 'سپر خودرو', 'لامپ و چراغ خودرو', 'طلق و شیشه چراغ خودرو', 'شیشه خودرو', 'چراغ راهنما موتور سیکلت', 'ایربگ خودرو']
# --------------------------------------------------
# Cluster 93:
# ['سایر کفش و صندل زنانه', 'سایر کفش مردانه', 'کفش کالج و روزمره مردانه', 'کفش طبی زنانه']
# --------------------------------------------------
# Cluster 94:
# ['اتو', 'سایر لوازم تهویه، سرمایش و گرمایش', 'آبمیوه گیری', 'رادیاتور پنلی و پره\u200cای', 'دتکتور دود و گاز', 'ماشین ظرف\u200c\u200cشویی', 'لوازم یدکی آشپزخانه', 'اجاق گاز', 'تصفیه\u200c\u200c هوا', 'پکیج دیواری و زمینی', 'لوازم یدکی جارو برقی، جاروشارژی و بخارشوی', 'پلوپز و مولتی کوکر', 'محافظ، پریز، کلید و چندراهی برق', 'سشوار', 'کتری برقی', 'تجهیزات آتش نشانی و اعلام حریق', 'بخارپز، آرام\u200cپز و هوا\u200cپز برقی', 'اسپند سوز', 'بخاری آکواریوم', 'فن کویل', 'هواکش و فن تهویه', 'سماور و بویلر صنعتی', 'هود آشپزخانه', 'لوازم یدکی ماشین لباسشویی و ظرفشویی', 'فر برقی و گازی', 'هیتر و هویه', 'کولر آبی', 'داکت اسپلیت', 'آبسرد کن', 'یونیت هیتر', 'آبگرمکن گازی', 'سماور گازی و زغالی', 'بخاری گازی']
# --------------------------------------------------
# Cluster 95:
# ['کیف و کاور گوشی', 'کیف و کاور تبلت', 'قاب، شاسی و درب گوشی', 'پایه نگهدارنده گوشی و تبلت']
# --------------------------------------------------
# Cluster 96:
# ['ساعت مچی عقربه\u200c ای و دیجیتالی']
# --------------------------------------------------
# Cluster 97:
# ['رادیاتور حوله\u200cای', 'وان و جکوزی حمام', 'قفسه حمام', 'شیر حمام', 'روکش و کاور توالت فرنگی', 'توالت فرنگی', 'توالت ایرانی']
# --------------------------------------------------
# Cluster 98:
# ['تابلو و مجسمه', 'فایل\u200cهای دانلودی', 'ماگ', 'سایر انواع ماکت']
# --------------------------------------------------
# Cluster 99:
# ['لوازم جانبی کنسول', 'سایر اسباب\u200cبازی و سرگرمی', 'دسته بازی (گیم پد)', 'بازی پلی استیشن', 'بازی Xbox', 'دسته بازی مخصوص موبایل', 'برچسب و کاور کنسول', 'کنسول بازی  PS4', 'مونوپاد و گیمبال موبایل', 'ماوس پد', 'اکشن فیگور', 'ماشین کنترلی']
# --------------------------------------------------
# Cluster 100:
# ['بکس برقی و شارژی', 'ست بکس و آچار بکس', 'بکس بادی']
# --------------------------------------------------
# Cluster 101:
# ['شارژر لپ تاپ', 'باتری لپ تاپ']
# --------------------------------------------------
# Cluster 102:
# ['تابلو فرش', 'گلیم، جاجیم و گبه', 'فرش نمدی', 'روفرشی', 'فرش ماشینی', 'فرش دستبافت', 'تجهیزات بافت فرش', 'موکت']
# --------------------------------------------------
# Cluster 103:
# ['صندل و دمپایی مردانه', 'صندل و دمپایی زنانه']
# --------------------------------------------------
# Cluster 104:
# ['سایر لوازم صوتی و تصویری خودرو', 'سایر لوازم جانبی سیستم های صوتی و تصویری', 'میکروفن', 'کارت صدا کامپیوتر', 'پخش\u200cکننده MP3 و MP4', 'اسپیکر و سیستم صوتی', 'پکیج استودیویی', 'سایر کابل\u200cهای سیستم\u200cهای صوتی و تصویری', 'ماژول صوتی و تصویری', 'پخش خودرو', 'ریموت کنترل پخش خودرو', 'دانگل بلوتوث']
# --------------------------------------------------
# Cluster 105:
# ['کابل شبکه', 'کابل و سیم تلفن', 'سیم و کابل برق ساختمان', 'کابل کواکسیال', 'ریسه و شلنگ نوری', 'کابل و آنتن تلویزیون']
# --------------------------------------------------
# Cluster 106:
# ['مانتو، پانچ و رویه']
# --------------------------------------------------
# Cluster 107:
# ['لباس فوتبال', 'جوراب فوتبال']
# --------------------------------------------------
# Cluster 108:
# ['سیم کارت همراه اول', 'بسته اینترنت', 'سیم کارت ایرانسل']
# --------------------------------------------------
# Cluster 109:
# ['ساعت و مچ بند هوشمند', 'خشاب سیم کارت', 'برد گوشی', 'اندروید باکس', 'تاچ و ال سی دی گوشی و تبلت', 'شیشه دوربین گوشی و تبلت', 'فلش مموری', 'تلویزیون', 'کیف و کاور گوشی', 'قاب، شاسی و درب گوشی', 'کارت حافظه و رم', 'گوشی موبایل', 'پایه نگهدارنده گوشی و تبلت', 'محافظ لنز دوربین', 'باتری گوشی موبایل', 'فلت گوشی', 'سنسور اثر انگشت گوشی']
# --------------------------------------------------
# Cluster 110:
# ['تایمر و تقویم دیجیتال', 'ساعت مچی عقربه\u200c ای و دیجیتالی', 'ترازو نوزاد']
# --------------------------------------------------
# Cluster 111:
# ['کارت خوان و صندوق فروشگاهی', 'کارت سانترال', 'هاب USB', 'کابل و تبدیل AUX', 'سایر انواع آی سی و میکروکنترلر', 'کابل و تبدیل USB', 'کابل شبکه', 'پکیج سیستم\u200cهای نظارتی و امنیتی', 'کابل و تبدیل Type C', 'مودم ADSL/VDSL', 'سایر کابل\u200cهای سیستم\u200cهای صوتی و تصویری', 'مودم LTE/3G/4G/5G', 'سایر تجهیزات شبکه و ارتباطات', 'دانگل کارت شبکه (Wifi)', 'میکروکنترلر ARM / STM', 'کابل و تبدیل HDMI']
# --------------------------------------------------
# Cluster 112:
# ['سه چرخه', 'چهارپایه', 'سه نظام']
# --------------------------------------------------
# Cluster 113:
# ['زیرانداز و تشک تعویض کودک', 'سرویس خواب کودک و نوزاد', 'سایر سیسمونی و مراقبت کودک', 'آویز تخت کودک', 'تخت خواب کودک و نوزاد', 'مبلمان کودک', 'تشک کودک و نوزاد', 'محافظ تخت و کوسن کودک', 'بالش کودک و نوزاد', 'پتو کودک و نوزاد', 'سرویس حوله عروس و داماد']
# --------------------------------------------------
# Cluster 114:
# ['روکش و تزیینات داشبورد', 'کفپوش خودرو', 'داشبورد خودرو', 'جلو پنجره خودرو', 'آرم خودرو', 'سایر تجهیزات راحتی سرنشین', 'روکش صندلی خودرو']
# --------------------------------------------------
# Cluster 115:
# ['گوشت گوسفندی', 'زرشک', 'فایل\u200cهای دانلودی', 'نودل', 'سبزی پلویی']
# --------------------------------------------------
# Cluster 116:
# ['نایلون دسته دار', 'ظروف نگهداری و حمل غذا', 'آبکش، لگن و سبد', 'سفره یکبار مصرف', 'قوطی و بطری پلاستیکی', 'دانخوری پرنده', 'آبخوری پرنده', 'دبه و سطل پلاستیکی', 'قیف و ماسوره']
# --------------------------------------------------
# Cluster 117:
# ['واشر درب سوپاپ خودرو', 'سرسیلندر خودرو', 'موتور فن بخاری و کولر خودرو', 'سایر لوازم یدکی خودرو', 'جراغ خطر اسپرت خودرو', 'فایل\u200cهای دانلودی', 'شمع خودرو', 'تسمه تایم خودرو', 'استارت خودرو', 'سر پلوس و گردگیر پلوس خودرو', 'سنسور دریچه گاز خودرو', 'سوپاپ تخلیه فشار خودرو', 'واشر سرسیلندر خودرو', 'سایر مشتقات ترمز خودرو', 'درب رادیاتور خودرو', 'شیلنگ بنزین خودرو', 'درجه داخل باک خودرو', 'استپر موتور خودرو', 'شیلنگ رادیاتور خودرو', 'پمپ ترمز خودرو', 'سیم گاز خودرو', 'دسته موتور خودرو', 'محتوای آموزشی', 'کاسه نمد سوپاپ خودرو', 'واشر کارتل خودرو', 'قطعات CNG خودرو', 'بوش طبق خودرو', 'رادیاتور آب خودرو', 'واشر و کاسه نمد', 'سنسور میل سوپاپ خودرو', 'فیوز و جعبه فیوز خودرو', 'کوئل خودرو', 'وایر شمع خودرو']
# --------------------------------------------------
# Cluster 118:
# ['ظروف تزیینی', 'سفره یکبار مصرف', 'سفره', 'جا جواهری', 'جای نان']
# --------------------------------------------------
# Cluster 119:
# ['کش ورزشی', 'لباس زیر و لباس خواب زنانه', 'تاپ ورزشی مردانه', 'کراوات', 'حوله تن پوش', 'شلوار و سرهمی زنانه', 'پوشاک ست زنانه و مردانه', 'کت و شلوار مردانه', 'گن و شکم بند لاغری', 'شلوارک مردانه', 'تاپ و تیشرت ورزشی زنانه', 'پیراهن مردانه', 'لباس شنا مردانه و پسرانه', 'لگینگ و ساپورت زنانه', 'شلوار رسمی و راحتی مردانه', 'ژاکت و پلیور مردانه', 'شلوار و لگ ورزشی زنانه', 'ژاکت و پلیور زنانه', 'کمربند زنانه', 'هدبند', 'کمربند مردانه', 'لباس زیر دخترانه', 'کت و جلیقه زنانه', 'مارک لباس', 'تاپ و تیشرت زنانه', 'سایر پوشاک مردانه', 'شلوارک زنانه', 'سویشرت و هودی مردانه', 'سویشرت و شلوار ورزشی مردانه', 'لباس زیر مردانه', 'جوراب مردانه', 'بلوز و پیراهن زنانه', 'لباس دوچرخه سواری', 'کاپشن، بارانی و پالتو مردانه', 'لباس شنا زنانه و دخترانه', 'پیشبند کودک']
# --------------------------------------------------
# Cluster 120:
# ['تاپر کیک', 'لوازم شمع سازی', 'سایر ابزار قنادی', 'بستنی خوری', 'وردنه آشپزی', 'استند و تخته سرو', 'جعبه پذیرایی']
# --------------------------------------------------
# Cluster 121:
# ['شمع و جاشمعی', 'عود و جاعودی']
# --------------------------------------------------
# Cluster 122:
# ['سایر پوشاک خردسال و نوجوان']
# --------------------------------------------------
# Cluster 123:
# ['شمع و جاشمعی', 'مکرومه بافی', 'سجاده و جانماز', 'سفره', 'چوب لباسی و آویز لباس', 'نشانگر کتاب', 'جاقلمی رومیزی', 'حوله دستی', 'ملحفه و روتختی', 'ملزومات پرده', 'ست رومیزی اداری', 'کوسن', 'دیوار کوب', 'ماسک پارچه\u200cای', 'فرش کودک', 'روبالشی', 'انواع پارچه', 'منسوجات آشپزخانه', 'پاف و بین بگ', 'رومیزی و پرده', 'سایر لوازم تزیینی منزل', 'میز کامپیوتر و تحریر', 'لوح تقدیر', 'پرده حمام']
# --------------------------------------------------
# Cluster 124:
# ['قند و شکر', 'بیکینگ پودر', 'پودر میوه جات', 'وانیل', 'سایر انواع شیرینی', 'هل', 'فلفل', 'سرکه', 'عسل', 'آرد و پودر سوخاری', 'شربت', 'نمک خوراکی', 'پودر اکلیل', 'سایر تخمه', 'زردچوبه', 'دارچین', 'شیرین کننده رژیمی']
# --------------------------------------------------
# Cluster 125:
# ['برس و ابزار آرایشی', 'لوازم جانبی دستگاه\u200cهای زیبایی', 'ناخن\u200cگیر و سوهان', 'پدیکور و مانیکور', 'فرمژه', 'سرم و تقویت کننده مو', 'شانه و برس سگ و گربه', 'ترولی آرایشگاهی', 'برس و کاسه رنگ', 'پاراوان و پارتیشن', 'سایر لوازم و تجهیزات زیبایی و آرایش', 'استند لوازم آرایشی', 'قیچی آرایشگری', 'ماساژور و لوازم ماساژ', 'تیغ و ژیلت', 'لوازم جانبی اصلاح و پیرایش', 'قلم مو هنری', 'آبپاش و پیشبند آرایشگاهی', 'شانه و برس', 'فیس براش', 'موچین', 'کوکتل و نمک حمام', 'اتو و صاف کننده مو']
# --------------------------------------------------
# Cluster 126:
# ['کوسن', 'روفرشی', 'پشتی و سرویس شاه\u200cنشین', 'فرش آشپزخانه']
# --------------------------------------------------
# Cluster 127:
# ['مام و اسپری', 'عطر و اسپری کودک', 'محافظ و پد سینه', 'قهوه', 'سایر رنگ مو', 'زناشویی']
# --------------------------------------------------
# Cluster 128:
# ['سماور گازی و زغالی', 'توری و سیخ کباب', 'منقل و زغال سوز', 'بخاری نفتی و هیزمی', 'اتو برنجی و زغالی']
# --------------------------------------------------
# Cluster 129:
# ['سایر پوشاک زنانه', 'پیراهن مردانه', 'کفش فوتبال', 'پیراهن پسرانه', 'شلوار پسرانه']
# --------------------------------------------------
# Cluster 130:
# ['بالش گردنی', 'جاسوزنی', 'کوسن', 'پشه بند', 'بالش', 'روفرشی', 'ساس بند', 'پادری', 'بالش بارداری', 'تاب ریلکسی', 'پتو مسافرتی', 'پیشبند کودک']
# --------------------------------------------------
# Cluster 131:
# ['تابلو و مجسمه', 'برچسب و لیبل', 'فایل\u200cهای دانلودی']
# --------------------------------------------------
# Cluster 132:
# ['مرطوب\u200cکننده و آبرسان', 'صابون', 'پاک\u200cکننده و شستشوی صورت']
# --------------------------------------------------
# Cluster 133:
# ['لامپ مادون قرمز', 'ریموت کنترل', 'فشارسنج پزشکی', 'آنتن و تقویت کننده شبکه', 'تجهیزات جانبی ماینینگ', 'ابزار دقیق و اندازه\u200cگیری', 'ریسه و شلنگ نوری', 'سایر تجهیزات شبکه و ارتباطات', 'ضبط کننده ویدیویی دوربین\u200cهای نظارتی و امنیتی', 'سنسور القایی', 'عینک ایمنی', 'دزدگیر اماکن و لوازم جانبی', 'سایر لوازم جانبی و قطعات ویدیو پروژکتور', 'ضبط\u200cکننده صدا', 'دزدگیر خودرو و لوازم جانبی', 'میکروفن', 'سایر عینک و لوازم جانبی', 'پنل آیفون صوتی و تصویری', 'آمپلی فایر خودرو', 'رادیو و گرامافون', 'اسپیکر و سیستم صوتی', 'کابل و تبدیل Lightning', 'دستگاه ماینر', 'سایر کابل\u200cهای سیستم\u200cهای صوتی و تصویری', 'هدلایت خودرو', 'سایر تجهیزات خانه هوشمند', 'گیرنده و فرستنده صدا', 'تجهیزات آتش نشانی و اعلام حریق', 'سایر تلویزیون و لوازم جانبی', 'ابزار و تجهیزات تعمیر موبایل', 'دریل و پیچ گوشتی برقی و شارژی', 'شارژر وایرلس و پایه شارژ', 'دوربین\u200c مدار بسته', 'تلفن تحت شبکه', 'آکواریوم و لوازم جانبی', 'سایر تجهیزات استودیویی', 'پروژکتور و وال واشر', 'سایر ماژول ال ای دی', 'تابلو و مجسمه', 'لوازم جانبی ساعت های معمولی و هوشمند', 'مکان\u200c یاب و قبله نما', 'کار کیت بلوتوثی خودرو', 'تلفن بی\u200cسیم', 'تلفن رومیزی', 'کارت خوان و صندوق فروشگاهی', 'ساب و بلندگو خودرو', 'عدسی عینک', 'صندلی مدیریتی', 'تجهیزات جانبی فیلمبرداری', 'لامپ LED', 'پکیج آیفون صوتی و تصویری']
# --------------------------------------------------
# Cluster 134:
# ['سایر لامپ و چراغ', 'پروژکتور و وال واشر', 'تابلو LED و لوازم جانبی', 'چراغ پنلی', 'چراغ قوه و چراغ پیشانی', 'پروژکتور و مه شکن خودرو', 'لامپ و چراغ خورشیدی', 'نورافکن و چراغ پلیسی خودرو', 'هدلایت خودرو', 'چراغ ال وایر خودرو', 'تجهیزات جانبی فیلمبرداری', 'لامپ چراغ خودرو', 'چراغ سقفی', 'چراغ مه شکن اسپرت خودرو', 'چراغ اضطراری و شارژی', 'فلاشر و آژیر', 'سوکت چراغ خودرو']
# --------------------------------------------------
# Cluster 135:
# ['درب خودرو', 'بوق خودرو', 'شمع خودرو', 'کاور و قاب ریموت خودرو', 'قفل فرمان و پدال خودرو', 'نرم افزار', 'چراغ خطر عقب خودرو', 'چراغ سقفی اسپرت خودرو', 'قفل رینگ خودرو', 'سایر لوازم تزئینی خودرو', 'هدلایت خودرو', 'چادر خودرو', 'سایر تجهیزات راحتی سرنشین', 'ماشین کنترلی', 'تخته شاسی', 'طبق خودرو', 'فیلتر هوا خودرو', 'سپر خودرو', 'رینگ اسپرت خودرو', 'موتور سیکلت', 'پخش خودرو', 'فندک و لوازم جانبی', 'کلاسور', 'بخاری برقی', 'سایر لوازم خودرو', 'آرم خودرو', 'ماکت ماشین', 'برف پاک کن خودرو', 'ماشین شارژی', 'اون توستر']
# --------------------------------------------------
# Cluster 136:
# ['فایل\u200cهای دانلودی', 'آلبوم عکس']
# --------------------------------------------------
# Cluster 137:
# ['کارواش و لوازم جانبی خودرو', 'تجهیزات و قطعات رباتیک', 'سایر ماشین\u200cها و تجهیزات اداری', 'ابزار و تجهیزات تعمیر موبایل', 'قطعات و لوازم جانبی الپتیکال', 'سایر قطعات صنعتی', 'فلاش تانک و لوازم جانبی', 'لوازم جانبی درب برقی', 'قطعات و لوازم جانبی تردمیل', 'تجهیزات تعمیرگاهی خودرو', 'سایر الکتروموتور و لوازم جانبی', 'قطعات و لوازم جانبی پنکه', 'قطعات و لوازم نصب رادیاتور', 'ادوات و ماشین\u200cآلات کشاورزی', 'لوازم جانبی و قطعات کولر', 'تجهیزات آسانسور و پله برقی', 'تجهیزات جانبی فیلمبرداری', 'لوازم جانبی و قطعات پمپ']
# --------------------------------------------------
# Cluster 138:
# ['شیلنگ و شیلنگ جمع کن', 'سایر تجهیزات پنوماتیک', 'جک سوسماری و روغنی', 'ترمینال ریلی و شاخه\u200cای', 'داکت و ترانکینگ', 'گیربکس صنعتی', 'قطعات و لوازم جانبی الپتیکال', 'تجهیزات راهنمای خطی', 'باسکول', 'تجهیزات آسانسور و پله برقی', 'بالابر و پولیفت', 'جک چهار میل پنوماتیک', 'نردبان', 'جک بازویی و پارکینگی', 'ساک و چرخ خرید', 'شیر برقی', 'تجهیزات تعمیرگاهی خودرو', 'رک و سازه باشگاهی', 'جک کابینت', 'تجهیزات چابکی و تعادلی']
# --------------------------------------------------
# Cluster 139:
# ['نردبان', 'تجهیزات نظامی', 'پرچم تشریفات', 'پرگار', 'خرمهره', 'پلاک و زنجیر', 'فایل\u200cهای دانلودی', 'پیکسل', 'کارتابل', 'مهره مار', 'سفره', 'کتابخانه', 'بازوبند و جای دعا', 'سرور', 'صدف', 'تسبیح']
# --------------------------------------------------
# Cluster 140:
# ['دستکش ایمنی', 'کفش ایمنی و کار', 'سایر ابزار و تجهیزات ایمنی', 'کلاه کاسکت']
# --------------------------------------------------
# Cluster 141:
# ['زاج', 'سبوس، جوانه و سویق', 'برنج ایرانی', 'کشک', 'تخمه آفتابگردان', 'جای برنج', 'آرد', 'غلات', 'برنج خارجی', 'لپه', 'زعفران', 'روغن خوراکی']
# --------------------------------------------------
# Cluster 142:
# ['جا لیوانی و لیوان خودرو', 'ظروف تزیینی', 'پارچ و لیوان', 'سینی پذیرایی', 'کتری و قوری', 'دمنوش ساز', 'سرویس چای خوری']
# --------------------------------------------------
# Cluster 143:
# ['رادیاتور بخاری خودرو', 'اتو', 'سایر لوازم یدکی خودرو', 'فن رادیاتور خودرو', 'روغن صنعتی', 'گیج روغن خودرو', 'شیلنگ بنزین خودرو', 'مکش هوای خودرو', 'فیلتر روغن خودرو', 'اویل پمپ خودرو', 'فیلتر هوا خودرو', 'منیفولد خودرو', 'واتر پمپ خودرو', 'فیلتر کابین خودرو', 'مقاومت فن رادیاتور خودرو', 'رادیاتور آب خودرو', 'پمپ بنزین خودرو', 'تجهیزات تعمیرگاهی خودرو', 'روغن موتور خودرو', 'فیلتر سوخت خودرو']
# --------------------------------------------------
# Cluster 144:
# ['دوربین گوشی و تبلت', 'کیف و کاور گوشی', 'قاب، شاسی و درب گوشی', 'بازر و بلندگو گوشی و تبلت', 'شارژر گوشی', 'کیف و کاور تبلت', 'سایر لوازم جانبی موبایل و تبلت', 'فلت گوشی']
# --------------------------------------------------
# Cluster 145:
# ['ساعت مچی عقربه\u200c ای و دیجیتالی']
# --------------------------------------------------
# Cluster 146:
# ['رگولاتور', 'فازمتر', 'فتوسل', 'سایر قطعات الکترونیکی', 'کتاب و مجلات']
# --------------------------------------------------
# Cluster 147:
# ['فایل\u200cهای دانلودی']
# --------------------------------------------------
# Cluster 148:
# ['ترمز فرش و پله', 'روکش و تزیینات داشبورد', 'کفپوش خودرو', 'زیرپایی اداری']
# --------------------------------------------------
# Cluster 149:
# ['اکشن فیگور']
# --------------------------------------------------
# Cluster 150:
# ['پایه چرخ خیاطی', 'کش خیاطی', 'سنجاق قفلی', 'جاسوزنی', 'بادبزن', 'جعبه خیاطی', 'خط کش', 'کلاسور', 'گیره آویز لباس', 'ساس بند', 'دکمه لباس', 'نخ قرقره', 'قیچی خیاطی', 'گیره کاغذ', 'زیپ', 'نخ سردوز']
# --------------------------------------------------
# Cluster 151:
# ['مداد پاک کن', 'گوش پاک کن', 'بادکنک', 'خودکار']
# --------------------------------------------------
# Cluster 152:
# ['سایر جوراب ورزشی', 'دستکش بدنسازی', 'کفش تنیس', 'تاپ ورزشی مردانه', 'کفش کوهنوردی', 'کفش مجلسی مردانه', 'جا جواهری', 'هدبند ورزشی', 'کفش طبی مردانه', 'کفش بدمینتون', 'کفش سنگ نوردی', 'مچ بند ورزشی', 'کفش کالج و روزمره مردانه', 'دستکش بوکس', 'کفش فوتبال', 'کفش والیبال', 'لباس بسکتبال', 'سایر کفش مردانه', 'ست لباس ورزشی مردانه', 'کفی و زیره کفش', 'جوراب مردانه', 'سایر لباس ورزشی مردانه']
# --------------------------------------------------
# Cluster 153:
# ['کتاب و مجلات', 'فکری، پازل و لگو']
# --------------------------------------------------
# Cluster 154:
# ['تخم بلدرچین', 'سایر غذا و مکمل حیوانات خانگی', 'غذای همستر', 'تخم سایر پرندگان', 'کود و مکمل آکواریوم', 'غذای طوطی سانان', 'سایر تجهیزات نگهداری حیوانات خانگی', 'غذا و تشویقی گربه', 'غذا و تشویقی سگ', 'غذای ماهی و میگو', 'قطعات شیر دوش دام']
# --------------------------------------------------
# Cluster 155:
# ['سایر ابزار دستی و تجهیزات کارگاهی', 'سایر ابزار و لوازم جانبی دوخت و دوز', 'پارچه قلمکار', 'تور و نوار تزئینی لباس']
# --------------------------------------------------
# Cluster 156:
# ['سایر لوازم جانبی کامپیوتر و لپ تاپ', 'کیف و کاور گوشی', 'رینگ لایت و لوازم جانبی', 'مانیتور خودرو', 'کاور و لوازم جانبی ایرپاد', 'سایر لوازم جانبی موبایل و تبلت']
# --------------------------------------------------
# Cluster 157:
# ['لگینگ و ساپورت زنانه', 'لباس زیر مردانه', 'کت و شلوار مردانه', 'ست لباس ورزشی مردانه', 'شلوار و سرهمی زنانه', 'گن و شکم بند لاغری', 'کت و جلیقه زنانه', 'شلوار رسمی و راحتی مردانه', 'شلوار و لگ ورزشی زنانه', 'شورت و شلوارک ورزشی زنانه', 'شلوارک پسرانه', 'شلوار پسرانه']
# --------------------------------------------------
# Cluster 158:
# ['شمع و جاشمعی', 'ماگ', 'سایر انواع ماکت', 'پرچم تشریفات', 'دیوار کوب', 'ظروف تزیینی', 'تابلو و مجسمه', 'مگنت', 'ابزار ماکت سازی']
# --------------------------------------------------
# Cluster 159:
# ['دستگاه سانترال', 'سنسور چشمی حرکتی', 'کیف و کاور تجهیزات فیلمبرداری', 'ضبط کننده ویدیویی دوربین\u200cهای نظارتی و امنیتی', 'شیشه دوربین گوشی و تبلت', 'لوازم جانبی فکس', 'سایر تجهیزات خانه هوشمند', 'میکروسکوپ', 'گیرنده دیجیتال', 'قلم نوری', 'وبکم و دوربین\u200cهای کنفرانس', 'اتوماسیون صنعتی', 'دوربین گوشی و تبلت', 'باتری دوربین', 'ماژول و سنسور نور و رنگ', 'دستگاه ویدیو پروژکتور', 'لنز دوربین', 'تلسکوپ', 'محافظ لنز دوربین', 'سه پایه دوربین', 'ماژول WIFI و بلوتوث', 'دوربین عکاسی و فیلمبرداری', 'تجهیزات جانبی فیلمبرداری']
# --------------------------------------------------
# Cluster 160:
# ['تشک دو نفره', 'تخت ماساژ و زیبایی', 'تشک میهمان', 'بالش طبی', 'کوسن', 'محافظ تشک', 'تشک و شناور روی آب', 'پشه بند', 'پتو دو نفره', 'مبلمان بادی', 'تشک مواج طبی', 'سایر انواع تشک', 'تشک بادی و مسافرتی', 'تشک تک نفره', 'تاب ریلکسی', 'تخت خواب', 'بالش بادی و مسافرتی', 'سایر انواع پتو']
# --------------------------------------------------
# Cluster 161:
# ['پاف و بین بگ', 'فوم رولر', 'زیپ کیپ', 'موکت']
# --------------------------------------------------
# Cluster 162:
# ['کوکتل و مواد ویتامینه', 'هات چاکلت', 'گینر', 'جلبک', 'مکمل کلاژن', 'گرانولا', 'سوسیس و کالباس', 'پن شستشو', 'اکسیدان', 'سایر نوشیدنی', 'سس', 'مکمل کربوهیدرات', 'شیرین کننده رژیمی', 'اسلایم', 'پروتئین وی']
# --------------------------------------------------
# Cluster 163:
# ['سایر انواع گردنبند', 'سایر دستبند، پابند و آویز ساعت']
# --------------------------------------------------
# Cluster 164:
# ['کارواش و لوازم جانبی خودرو', 'اتو و جوش لوله', 'سایر ابزار و لوازم شستشو و نظافت', 'سایر یراق آلات', 'دستگاه\u200cهای بسته\u200cبندی و شیرینگ', 'فایل\u200cهای دانلودی', 'گریل', 'کوپلینگ و واسطه', 'ابزار دقیق و اندازه\u200cگیری', 'روغن صنعتی', 'ادوات و ماشین\u200cآلات کشاورزی', 'مواد و تجهیزات دندانپزشکی', 'سایر لوازم صافکاری', 'تجهیزات آتش نشانی و اعلام حریق', 'واحد مراقبت پنوماتیک', 'سیم چین و کف چین', 'قطعات یدکی پشم چین', 'سایر ابزار دستی و تجهیزات کارگاهی', 'اینورتر و دستگاه جوشکاری', 'سایر ابزار و تجهیزات ایمنی', 'کتاب و مجلات']
# --------------------------------------------------
# Cluster 165:
# ['مبلمان باغی و فضای باز', 'سایر  مبل راحتی', 'کمد، بوفه و قفسه دیواری', 'ست سرویس آشپزخانه', 'ست میز و صندلی غذاخوری', 'سایر صندلی', 'میز تلویزیون', 'سینی پذیرایی', 'مبلمان بادی', 'تخته کار آشپزخانه', 'سایر مبلمان', 'صندلی کانتر و اپنی', 'سرویس غذاخوری', 'دراور و کشو', 'کابینت آشپزخانه', 'آینه کنسول', 'مبلمان اداری', 'مبل کلاسیک']
# --------------------------------------------------
# Cluster 166:
# ['ترازو فروشگاهی', 'ترازو آشپزخانه', 'ترازو وزن کشی خانگی']
# --------------------------------------------------
# Cluster 167:
# ['محصولات مسی']
# --------------------------------------------------
# Cluster 168:
# ['پارچ و لیوان', 'ماگ', 'ظروف یکبار مصرف']
# --------------------------------------------------
# Cluster 169:
# ['مکرومه بافی', 'سجاده و جانماز', 'پیکسل', 'سایر لوازم مناسبت\u200cهای مذهبی', 'نوار اریب', 'آویز و جاکلیدی', 'بانکه و ظروف بنشن', 'مهره و سنگ تزیینی لباس', 'بشکاف خیاطی', 'پولک و منجوق', 'چادر', 'پادری', 'پته دوزی', 'زیپ', 'کاربن خیاطی', 'انواع پارچه', 'نخ سردوز', 'تریکو بافی', 'شال', 'جعبه خیاطی', 'ساک و چرخ خرید', 'شانه و برس', 'کاموا', 'پوشه', 'تور و نوار تزئینی لباس', 'روسری', 'نخ کوبلن و گلدوزی']
# --------------------------------------------------
# Cluster 170:
# ['ارگ و کیبورد اسباب بازی', 'ست ماوس و کیبورد', 'ماوس', 'کامپیوتر دسکتاپ', 'کیبورد', 'کیف و کاور لپ تاپ', 'پایه نگهدارنده مانیتور و لپ تاپ', 'فیس براش', 'دستکش و کاور انگشت مخصوص بازی', 'دارت', 'ماوس پد', 'مونوپاد و گیمبال موبایل']
# --------------------------------------------------
# Cluster 171:
# ['چرخ خیاطی و ریسندگی', 'دینام و پدال چرخ خیاطی', 'روغن و روغن دان چرخ خیاطی', 'سوزن چرخ خیاطی', 'لوازم جانبی دستگاه کپی', 'میز اتو و چرخ خیاطی', 'نخ سردوز', 'سوزن کش']
# --------------------------------------------------
# Cluster 172:
# ['جعبه ابزار', 'ماوس', 'فیس براش', 'پیکسل', 'ترانسفر', 'ماوس پد', 'تجهیزات جانبی فیلمبرداری']
# --------------------------------------------------
# Cluster 173:
# ['کتاب و مجلات']
# --------------------------------------------------
# Cluster 174:
# ...
# --------------------------------------------------
# Cluster 952:
# ['سایر ابزار آشپزخانه', 'فرش آشپزخانه', 'پادری', 'منسوجات آشپزخانه', 'ترازو آشپزخانه']
# --------------------------------------------------
# Cluster 953:
# ['ساعت مچی عقربه\u200c ای و دیجیتالی']
# --------------------------------------------------
# Cluster 954:
# ['سی\u200c\u200cدی فیلم و سریال', 'محتوای آموزشی']
# --------------------------------------------------
# Cluster 955:
# ['اکشن فیگور', 'لوازم نقش آفرینی']
# --------------------------------------------------
# Cluster 956:
# ['یخچال فریزر بالاپایین', 'فر برقی و گازی', 'کولر آبی', 'هود آشپزخانه', 'اجاق برقی', 'لوستر و چراغ تزئینی', 'آبگرمکن گازی', 'اجاق گاز', 'بخاری گازی']
# --------------------------------------------------
# Cluster 957:
# ['شمع و جاشمعی', 'آینه دکوراتیو', 'قفل آویز', 'برس و ابزار آرایشی', 'پیکسل', 'چوب لباسی و آویز لباس', 'قلاب آویز', 'ریسه و شلنگ نوری', 'لوازم رزین', 'جاقلمی رومیزی', 'دفتر و کاغذ', 'آویز و جاکلیدی', 'پلاک و زنجیر', 'کریر و کالسکه', 'سایر عینک و لوازم جانبی', 'گیره آویز لباس', 'ست و نیم\u200c ست جواهرات', 'پودر اکلیل', 'عروسک پولیشی', 'استند لوازم آرایشی', 'لوستر و چراغ تزئینی', 'قاشق، چنگال و کارد', 'اسلایم', 'سایر لوازم جشن و هدیه', 'حنا و شابلون طراحی', 'کوسن', 'آباژور و چراغ خواب', 'گل سینه و گل سر', 'جاکفشی و جالباسی', 'نظم دهنده و باکس لباس', 'گلدان و گل مصنوعی', 'منسوجات آشپزخانه', 'سایر لوازم مربوط به جواهر و زیورآلات', 'سایر لوازم التحریر', 'لوازم جانبی و مصرفی سرو قهوه', 'عود و جاعودی', 'مانکن', 'ماگ', 'رنگ دکوراتیو', 'رومیزی و پرده', 'کلاسور', 'فندک و لوازم جانبی', 'سایر لوازم تزیینی منزل', 'پکیج کادویی', 'سایر انواع گردنبند', 'تراش']
# --------------------------------------------------
# Cluster 958:
# ['چای', 'کیسه زباله', 'فلاسک، قمقمه و ظروف سفر', 'شیکر و قمقمه ورزشی', 'بطری نوشیدنی', 'کتری و قوری', 'آبلیمو خوری و سس خوری', 'قاشق، چنگال و کارد', 'صافی چای']
# --------------------------------------------------
# Cluster 959:
# ['سایر اسباب\u200cبازی و سرگرمی', 'کش ورزشی', 'راکت بدمینتون', 'توپ فوتبال', 'توپ والیبال', 'توپ و حلقه تقویت مچ', 'تجهیزات یوگا', 'عینک شنا', 'استخر توپ', 'سایر دستکش ورزشی', 'کیف و ساک تنیس و بدمینتون', 'توپ پیلاتس و ایروبیک', 'فوتبال دستی']
# --------------------------------------------------
# Cluster 960:
# ['پوشک کودک و نوزاد', 'زناشویی']
# --------------------------------------------------
# Cluster 961:
# ['زیبایی و مراقبت ناخن', 'لیفت و لمینت مژه و ابرو', 'برس و ابزار آرایشی', 'ژل و ریمل ابرو', 'مژه مصنوعی و اکستنشن', 'فایل\u200cهای دانلودی', 'لوازم جانبی دستگاه\u200cهای زیبایی', 'لوازم کاشت مژه', 'چسب بینی', 'تقویت کننده مژه و ابرو', 'لیزر موهای زائد', 'تتو و میکروپگمنتیشن', 'سایر لوازم و تجهیزات زیبایی و آرایش', 'مراقبت دور چشم', 'کتاب و مجلات', 'لاک ژل']
# --------------------------------------------------
# Cluster 962:
# ['دریل و پیچ گوشتی برقی و شارژی', 'سایر کابل\u200cهای سیستم\u200cهای صوتی و تصویری', 'جک سوسماری و روغنی']
# --------------------------------------------------
# Cluster 963:
# ['گوشواره نقره', 'انگشتر نقره', 'دستبند سنگی و کریستال', 'دستبند نقره', 'انگشتر یاقوت', 'سایر انواع انگشتر', 'بند عینک', 'پلاک و زنجیر', 'سنگ فیروزه', 'گردنبند مروارید', 'انگشتر فیروزه', 'سایر لوازم مربوط به جواهر و زیورآلات', 'گردنبند نقره', 'انگشتر عقیق', 'سایر انواع گردنبند', 'سنگ عقیق', 'گردنبند طلا', 'سایر دستبند، پابند و آویز ساعت', 'سایر انواع گوشواره']
# --------------------------------------------------
# Cluster 964:
# ['تابلو و مجسمه']
# --------------------------------------------------
# Cluster 965:
# ['تیشرت و پولوشرت ورزشی', 'تیشرت و پولوشرت پسرانه', 'تیشرت و پولوشرت مردانه', 'شلوارک مردانه', 'تاپ و تیشرت زنانه', 'تاپ و تیشرت دخترانه']
# --------------------------------------------------
# Cluster 966:
# ['میکروفن گوشی و تبلت', 'فایل\u200cهای دانلودی', 'کابل و تبدیل OTG', 'شیشه دوربین گوشی و تبلت', 'دکمه پاور گوشی و تبلت', 'قاب، شاسی و درب گوشی', 'جک و سوکت گوشی و تبلت', 'برد گوشی', 'گلس تعمیراتی گوشی و تبلت', 'دوربین گوشی و تبلت', 'بازر و بلندگو گوشی و تبلت', 'آی سی گوشی و تبلت', 'باتری گوشی موبایل', 'فلت گوشی', 'کابل و اتصالات گوشی و تبلت', 'کیف و کاور گوشی', 'شارژر گوشی', 'گوشی موبایل', 'سایر قطعات گوشی و تبلت']
# --------------------------------------------------
# Cluster 967:
# ['مبل راحتی ال', 'سایر  مبل راحتی', 'صندلی و تخت استخری', 'مبل راحتی چستر', 'سایر مبلمان', 'میز جلو مبلی و عسلی', 'مبلمان اداری', 'مبل کلاسیک']
# --------------------------------------------------
# Cluster 968:
# ['آلبوم عکس', 'سایر انواع ماکت', 'فایل\u200cهای دانلودی', 'پیکسل', 'زیپ']
# --------------------------------------------------
# Cluster 969:
# ['جوهر نوشت افزار', 'دفتر و کاغذ', 'خودکار', 'خودنویس و روان نویس']
# --------------------------------------------------
# Cluster 970:
# ['تفنگ شکاری', 'تفنگ آبپاش', 'سایر تفنگ اسباب بازی', 'تفنگ ساچمه\u200cای', 'تجهیزات جانبی سلاح', 'تفنگ موزیکال']
# --------------------------------------------------
# Cluster 971:
# ['دمپایی و صندل خردسال و نوجوان', 'کفش کوهنوردی', 'صندل و دمپایی زنانه', 'کفش مجلسی مردانه', 'کتانی و کفش اسپرت مردانه', 'چمدان و ساک', 'کتانی و کفش اسپرت زنانه', 'کفش کالج و روزمره مردانه', 'کفش فوتبال', 'لباس بسکتبال', 'سایر کفش مردانه', 'صندل و دمپایی مردانه', 'ساق بند ورزشی', 'اسکیت کفشی و اسکیت بورد', 'سایر کفش و صندل زنانه', 'کتانی و کفش اسپرت', 'جوراب مردانه', 'سایر کفش و صندل خردسال و نوجوان', 'کفش پاشنه بلند و مجلسی زنانه', 'کفش بسکتبال']
# --------------------------------------------------
# Cluster 972:
# ['مربا', 'جلبک', 'میوه و تره بار', 'برگه زردآلو', 'آبمیوه', 'سایر میوه خشک', 'آجیل', 'اسانس خوراکی', 'شیر نارگیل', 'روغن خوراکی', 'زیتون', 'ماء الشعیر', 'موز خشک', 'سایر تنقلات', 'سیروپ', 'کمپوت آناناس', 'کشک', 'بادام', 'لیمو عمانی', 'شربت']
# --------------------------------------------------
# Cluster 973:
# ['باتری لپ تاپ', 'سایر قطعات و لوازم جانبی تلفن', 'کابل و اتصالات گوشی و تبلت', 'باتری گوشی موبایل', 'شارژر رومیزی', 'باتری قلمی، سکه\u200cای و کتابی', 'کابل و تبدیل USB', 'شارژر وایرلس و پایه شارژ', 'شارژر گوشی', 'شارژر فندکی خودرو', 'پایه نگهدارنده گوشی و تبلت', 'پاوربانک و شارژر همراه', 'جامپ استارتر و پاوربانک خودرو', 'پنکه', 'جاباتری و شارژر باتری', 'کابل شارژ پاور بانک']
# --------------------------------------------------
# Cluster 974:
# ['چشم بند خواب']
# --------------------------------------------------
# Cluster 975:
# ['واکر و عصا', 'چکش', 'ابزار چند کاره', 'گارو خونگیری', 'چمن زن و داس موتوری']
# --------------------------------------------------
# Cluster 976:
# ['سایر مصالح ساختمانی', 'سایر لوازم تهویه، سرمایش و گرمایش', 'اتو و جوش لوله', 'سیم لخت\u200cکن و پرس کابل', 'محصولات مسی', 'داکت و ترانکینگ', 'شیر فلکه', 'لوله و خرطومی برق', 'سایر شیرآلات', 'حفاظ ، نرده و جدول', 'سیم و کابل برق ساختمان', 'عایق الاستومری', 'لوازم جانبی شیرآلات', 'لرزه گیر', 'لوله و اتصالات', 'لوله خم کن', 'لوازم آبیاری و باغبانی', 'سایر ابزار و تجهیزات ایمنی', 'کابلشو و سرسیم']
# --------------------------------------------------
# Cluster 977:
# ['جاقلمی رومیزی', 'آویز و جاکلیدی', 'جاکفشی و جالباسی']
# --------------------------------------------------
# Cluster 978:
# ['موپران آرایشگاهی', 'اکشن فیگور']
# --------------------------------------------------
# Cluster 979:
# ['رادیاتور حوله\u200cای', 'حوله یکبار مصرف', 'جا حوله\u200cای و رخت آویز حمام', 'کلاه حمام', 'حوله تن پوش', 'حوله دستی', 'سایر حوله', 'حوله استخری', 'سبد لباس چند منظوره']
# --------------------------------------------------
# Cluster 980:
# ['باتری لپ تاپ', 'سایر قطعات لپ تاپ', 'ترک پد و تاچ لپ تاپ', 'فایل\u200cهای دانلودی', 'مادربورد', 'پیچ و لولای لپ تاپ', 'تاچ و ال سی دی لپ تاپ', 'تبلت', 'رم لپ تاپ', 'بایوس لپ تاپ', 'پاور ویندوز خودرو', 'برد گوشی', 'برد و کابل داخلی لپ تاپ', 'لپ تاپ و نوت بوک', 'لوازم جانبی هارد', 'کامپیوتر های All in one', 'محتوای آموزشی', 'کیبورد', 'ابزار و تجهیزات تعمیر موبایل', 'فن لپ تاپ', 'کیبورد لپ تاپ', 'کامپیوتر دسکتاپ', 'سایر لوازم جانبی پرینتر', 'فلش مموری', 'کیبورد تبلت', 'فلت لپ تاپ', 'برد توسعه']
# --------------------------------------------------
# Cluster 981:
# ['سرمه و سرمه دان', 'فیروزه کوبی', 'آینه دکوراتیو']
# --------------------------------------------------
# Cluster 982:
# ['تاچ و ال سی دی گوشی و تبلت', 'اندروید باکس', 'فایل\u200cهای دانلودی', 'آنتن گوشی و تبلت', 'کابل و تبدیل OTG', 'دکمه پاور گوشی و تبلت', 'جک و سوکت گوشی و تبلت', 'سایر لوازم جانبی موبایل و تبلت', 'دوربین گوشی و تبلت', 'بازر و بلندگو گوشی و تبلت', 'تلفن تحت شبکه', 'آی سی گوشی و تبلت', 'باتری گوشی موبایل', 'فلت گوشی', 'کارت صدا استودیو', 'تلفن بی\u200cسیم', 'تلفن رومیزی', 'سایر قطعات و لوازم جانبی تلفن', 'خشاب سیم کارت', 'شارژر گوشی', 'گوشی موبایل', 'کارت صدا کامپیوتر', 'پکیج آیفون صوتی و تصویری', 'سایر قطعات گوشی و تبلت']
# --------------------------------------------------
# Cluster 983:
# ['تابلو فرش', 'فرش ماشینی', 'موکت', 'محافظ ریشه فرش']
# --------------------------------------------------
# Cluster 984:
# ['کوسن', 'روفرشی']
# --------------------------------------------------
# Cluster 985:
# ['سنگ ساختمانی']
# --------------------------------------------------
# Cluster 986:
# ['شمع و جاشمعی', 'کیف پول و اقلام کوچک', 'فایل\u200cهای دانلودی', 'روفرشی', 'سایر عروسک', 'ماسک سه بعدی', 'کیف و کاور عینک', 'اسپرسو ساز', 'نوار اریب', 'جعبه و پاکت غذا', 'تزیینات عید نوروز', 'آینه کنسول', 'اردو خوری و رولت خوری', 'ظروف نگهداری و حمل غذا', 'حوله دستی', 'حلقه و جای دستمال سفره', 'عروسک پولیشی', 'پایه نگهدارنده گوشی و تبلت', 'قاشق، چنگال و کارد', 'کاغذ PH', 'تلفن کلاسیک و سلطنتی', 'تسبیح', 'جامدادی', 'موکت', 'کیف و کوله', 'ساک و جعبه هدیه', 'ست رومیزی اداری', 'کوسن', 'گل سینه و گل سر', 'آبمیوه گیری دستی', 'فرش ماشینی', 'فرش کودک', 'ترانسفر', 'گلدان و گل مصنوعی', 'زیر سیگاری', 'چسب ماتیکی', 'تابلو و مجسمه', 'حوله آشپزخانه', 'انواع پارچه', 'عروسک روسی', 'صندلی آموزشی', 'عروسک حیوانات', 'لوازم جانبی کنسول', 'سایر لوازم پرنده', 'مانکن', 'ماگ', 'پاکت اداری', 'ست سرویس بهداشتی', 'رومیزی و پرده', 'شکم بند بارداری', 'پارچ و لیوان', 'کفشور', 'شکار و لوازم ماهیگیری', 'پوشه', 'سایر کفش و صندل خردسال و نوجوان', 'رنگ مولتی سرفیس', 'تقویم و سالنامه', 'ماشین شارژی', 'کتاب و مجلات']
# --------------------------------------------------
# Cluster 987:
# ['سایر لوازم یدکی خودرو', 'بوق خودرو', 'واشر اگزوز خودرو', 'دریچه گاز خودرو', 'ترموستات خودرو', 'چراغ راهنما خودرو', 'سوزن انژکتور خودرو', 'سایر مشتقات ترمز خودرو', 'درب رادیاتور خودرو', 'روکش پدال خودرو', 'هواکش خودرو', 'تسمه کولر خودرو', 'چکش', 'سپر خودرو', 'پیچ و مهره قطعات موتور', 'پمپ بنزین خودرو', 'آرم خودرو', 'وایر شمع خودرو', 'خار و سایر قطعات بدنه']
# --------------------------------------------------
# Cluster 988:
# ['کیف آرایش', 'کیف وسایل کودک', 'پکیج کادویی', 'کیف و کوله']
# --------------------------------------------------
# Cluster 989:
# ['میز و صندلی آرایش', 'صندلی غذاخوری و رستورانی', 'میز و صندلی تاشو و مسافرتی', 'ست میز و صندلی غذاخوری']
# --------------------------------------------------
# Cluster 990:
# ['رژگونه', 'آرایش و مراقبت لب']
# --------------------------------------------------
# Cluster 991:
# ['لوازم جانبی ساعت های معمولی و هوشمند', 'سایر دستبند، پابند و آویز ساعت', 'ساعت مچی عقربه\u200c ای و دیجیتالی', 'اسباب بازی آموزشی']
# --------------------------------------------------
# Cluster 992:
# ['تخمه کدو', 'دانه چیا', 'شاهدانه', 'تخمه آفتابگردان', 'سایر ادویه جات', 'تخم کتان', 'میوه و تره بار', 'فایل\u200cهای دانلودی', 'سیاهدانه', 'فلفل', 'تخم گشنیز', 'غلات', 'موز خشک', 'پودر پیاز', 'تخم مرغ', 'دمنوش']
# --------------------------------------------------
# Cluster 993:
# ['قالپاق خودرو', 'لنت ترمز خودرو', 'سایر لوازم یدکی خودرو', 'بوق خودرو', 'شمع خودرو', 'استارت خودرو', 'بلبرینگ پلوس خودرو', 'سایر مشتقات ترمز خودرو', 'فنر لول خودرو', 'درب منبع روغن موتور خودرو', 'کمک فنر خودرو', 'طبق خودرو', 'دسته موتور خودرو', 'پا رکابی خودرو', 'سپر خودرو', 'کاتالیزور خودرو', 'کشویی دنده خودرو', 'سر دنده خودرو', 'سر اگزوز خودرو', 'آرم خودرو', 'دیسک ترمز خودرو']
# --------------------------------------------------
# Cluster 994:
# ['زیبایی و مراقبت ناخن', 'ترازو وزن کشی خانگی', 'سایر عروسک', 'صندل و دمپایی زنانه', 'پدیکور و مانیکور', 'فکری، پازل و لگو', 'سایر لوازم جانبی هدفون و هندزفری', 'کابل و تبدیل Lightning', 'اسپیکر و سیستم صوتی', 'سطل زباله', 'میکروسکوپ', 'جامپ استارتر و پاوربانک خودرو', 'قلم نوری', 'کیف و کوله', 'عینک طبی', 'ماساژور و لوازم ماساژ', 'کالیمبا', 'شامپو و نرم کننده کودک', 'شوینده ظروف', 'سایر لوازم جانبی ادوات موسیقی', 'فلش مموری', 'ماشین اصلاح و ریش\u200c تراش', 'سه پایه دوربین', 'مسواک', 'دوربین عکاسی و فیلمبرداری', 'حوله حمام', 'ساعت مچی عقربه\u200c ای و دیجیتالی', 'تجهیزات جانبی فیلمبرداری', 'مواد اولیه شیمیایی و پتروشیمی', 'کیف و کاور تبلت', 'سایر تجهیزات پزشکی', 'کلارینت', 'پایه نگهدارنده گوشی و تبلت', 'کاور و لوازم جانبی ایرپاد', 'ماشین کنترلی', 'سایر لوازم جانبی کامپیوتر و لپ تاپ', 'دریچه کولر خودرو', 'سایر کفش مردانه', 'تابلو و مجسمه', 'تلسکوپ', 'لوازم جانبی ساعت های معمولی و هوشمند', 'حافظه SSD', 'برچسب و استیکر موبایل و لپ تاپ', 'ساعت و مچ بند هوشمند', 'اپیلاتور', 'سرویس ابزار آشپزخانه', 'ساب و بلندگو خودرو', 'کیف و کاور لپ تاپ', 'دستمال مرطوب کودک', 'دوربین دنده عقب خودرو', 'کیف آرایش', 'اکشن فیگور', 'فرفره انفجاری', 'سایر دستگاه های سنجش سلامت و لوازم جانبی', 'کفش کالج و روزمره زنانه', 'ساز دهنی', 'جاباتری و شارژر باتری', 'کابل و تبدیل HDMI', 'میکروفن', 'مواد و تجهیزات دندانپزشکی', 'آرایش و مراقبت لب', 'چادر مسافرتی', 'زانو بند طبی', 'عطر ادوپرفیوم مردانه', 'گوشی پزشکی', 'انگشتر فیروزه', 'المنت و سر هویه', 'ماوس', 'پاپوش و کفش نوزاد و کودک', 'کیبورد تبلت', 'هدفون، هدست و هندزفری', 'اسباب بازی آموزشی', 'کاپشن، بارانی و پالتو مردانه', 'کتاب و مجلات', 'محافظ صفحه نمایش گوشی', 'کفش مجلسی مردانه', 'سایر لوازم الکتریکی همراه', 'کاور و قاب ریموت خودرو', 'روشنایی و نورپردازی هوشمند', 'تشک بادی و مسافرتی', 'لوازم جانبی اصلاح و پیرایش', 'گیتار', 'کیبورد', 'کتاب های صوتی و الکترونیکی', 'پاور کامپیوتر', 'قلم لمسی', 'آینه و روشویی', 'کاپشن و پالتو دخترانه', 'مانیتور', 'استند و پایه خنک کننده', 'کیف و کاور گوشی', 'جارو برقی', 'ردیاب خودرو']
# --------------------------------------------------
# Cluster 995:
# ['لوازم مجسمه سازی', 'قالب هنری', 'قالب شیرینی پزی و دسر', 'زیر سیگاری']
# --------------------------------------------------
# Cluster 996:
# ['مصالح پیش ساخته', 'خاتم کاری', 'آینه کنسول', 'مینا کاری']
# --------------------------------------------------
# Cluster 997:
# ['پرپشت کننده و حجم دهنده مو', 'کراتین و بوتاکس مو', 'سرم و تقویت کننده مو', 'شامپو و شاور بدن', 'صابون', 'رنگ مو', 'آرایش و مراقبت لب', 'لوسیون و روغن بدن', 'ماسک و لوسیون مو', 'حالت دهنده مو', 'شوینده و نرم کننده لباس و حوله', 'شامپو و نرم کننده کودک', 'لیف و کیسه حمام', 'مام و اسپری', 'روغن آرگان', 'شامپو و نرم کننده', 'موم و وکس', 'اتو و صاف کننده مو', 'شامپو رنگ مو']
# --------------------------------------------------
# Cluster 998:
# ['کلاسور', 'دفتر و کاغذ', 'قیچی خیاطی', 'کاغذ یادداشت']
# --------------------------------------------------
# Cluster 999:
# ['سرویس حوله نوزاد', 'پوشک کودک و نوزاد', 'تخت خواب کودک و نوزاد', 'جوراب نوزادی', 'کیف وسایل کودک', 'حوله کودک و نوزاد', 'حوله تن پوش کودک', 'پتو کودک و نوزاد', 'وان حمام کودک و نوزاد', 'پستانک و ملزومات', 'دستمال مرطوب کودک', 'شیر دوش کودک', 'کهنه کودک و نوزاد', 'کیسه خواب کودک و نوزاد', 'لباس نوزاد و کودک', 'پیشبند کودک']
# --------------------------------------------------
